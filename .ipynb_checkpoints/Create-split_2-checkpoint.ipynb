# %%
#--- 2025-09-13 02-24 – by Dr. Thawatchai Chomsiri
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, DepthwiseConv2D, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Activation
from tensorflow.keras.models import Model
import datetime

import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Flatten, Dense
import matplotlib.pyplot as plt
import datetime
import numpy as np
import os
import re
import math
import pickle

  
def lsgelu(x):    # Left-Shifted GELU with 1 range
    return x * 0.5 * (1 + tf.math.erf((x + 1.5) / tf.sqrt(2.0)))

def lsgelu9999(x):    
    S=3.71901648546
    return x * 0.5 * (1 + tf.math.erf((x + S) / tf.sqrt(2.0)))

def lsgelu9950(x):    
    S=2.57582930355
    return x * 0.5 * (1 + tf.math.erf((x + S) / tf.sqrt(2.0)))

def lsgelu9900(x):    
    S=2.32634787404
    return x * 0.5 * (1 + tf.math.erf((x + S) / tf.sqrt(2.0)))

def lsgelu9750(x):    
    S=1.95996398454
    return x * 0.5 * (1 + tf.math.erf((x + S) / tf.sqrt(2.0)))

def lsgelu9500(x):    
    S=1.64485362695
    return x * 0.5 * (1 + tf.math.erf((x + S) / tf.sqrt(2.0)))

#-----
def lsgelu9332(x): # LSGELU   
    S=1.5
    return x * 0.5 * (1 + tf.math.erf((x + S) / tf.sqrt(2.0)))

#-----
def lsgelu9250(x):    
    S=1.43953147094
    return x * 0.5 * (1 + tf.math.erf((x + S) / tf.sqrt(2.0)))

def lsgelu9000(x):    
    S=1.28155156554
    return x * 0.5 * (1 + tf.math.erf((x + S) / tf.sqrt(2.0)))

def lsgelu8000(x):    
    S=0.841621233573
    return x * 0.5 * (1 + tf.math.erf((x + S) / tf.sqrt(2.0)))

def lsgelu7500(x):    
    S=0.674489750196
    return x * 0.5 * (1 + tf.math.erf((x + S) / tf.sqrt(2.0)))

def lsgelu6666(x):    
    S=0.430727299295
    return x * 0.5 * (1 + tf.math.erf((x + S) / tf.sqrt(2.0)))

#-----
def lsgelu2(x):    # Left-Shifted GELU with 2 range
    return tf.where(
        x >= 0,
        x, 
        x * 0.5 * (1 + tf.math.erf((x + 1.5) / tf.sqrt(2.0)))
    ) 

def lsgelu3(x):    # Left-Shifted GELU with 3 range
    L = -3.00
    return tf.where(
        x >= 0,
        x,
        tf.where(
            x >= L,
            x * 0.5 * (1 + tf.math.erf((x + 1.5) / tf.sqrt(2.0))),
            tf.zeros_like(x)
        )
    ) 

# Function สำหรับสร้างโมเดล
def build_model(activation_fn):
    inputs = Input(shape=(32, 32, 3))
    x = Conv2D(32, (3, 3), strides=2, padding='same', activation=None)(inputs)
    x = BatchNormalization()(x)
    x = Activation(activation_fn)(x)

    def bottleneck_block(x, filters):
        dw = DepthwiseConv2D((3, 3), padding='same')(x)
        dw = BatchNormalization()(dw)
        dw = Activation(activation_fn)(dw)

        pw = Conv2D(filters, (1, 1), padding='same')(dw)
        pw = BatchNormalization()(pw)
        pw = Activation(activation_fn)(pw)
        return pw

    x = bottleneck_block(x, 64)
    x = bottleneck_block(x, 64)
    x = MaxPooling2D((2, 2))(x)
    x = bottleneck_block(x, 128)
    x = bottleneck_block(x, 128)

    x = GlobalAveragePooling2D()(x)
    outputs = Dense(10, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

activations_list = {
    "LSGELU9999": lsgelu9999,
    "LSGELU9950": lsgelu9950,
    "LSGELU9900": lsgelu9900,
    "LSGELU9750": lsgelu9750,
    "LSGELU9500": lsgelu9500,
    "LSGELU9332": lsgelu9332, # LSGELU
    "LSGELU9250": lsgelu9250,
    "LSGELU9000": lsgelu9000,
    "LSGELU8000": lsgelu8000,
    "LSGELU7500": lsgelu7500,
    "LSGELU6666": lsgelu6666,
    
    'GELU': tf.nn.gelu,
    'ELU': tf.nn.elu,
    'ReLU': tf.nn.relu,
    'Swish': tf.nn.swish,     
}

epochs = 101  ################
num_runs = 30 ###############
batch_size = 64 ###############
results = {
    'activation': [],
    'accuracy_per_epoch': []
}
accuracy_summary = {}

for run_idx in range(num_runs):
    print(f"\n--- Run {run_idx:03d} of {num_runs:03d} ---")
    results = {}
    accuracy_results = {}
    loss_results = {}
    
    for act_name, act_fn in activations_list.items():
        print(f"Running: Activation={act_name} at {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

        # เทรน
        model = build_model(act_fn)
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                            loss='sparse_categorical_crossentropy',
                            metrics=['accuracy'])

        history = model.fit(x_train, y_train, epochs=epochs, validation_data=(x_test, y_test), batch_size=batch_size)
        
        print(f"Running: Activation={act_name} at {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")   
        results[act_name] = {key: np.array(val) for key, val in history.history.items()}
        print(f"Details in results for round {run_idx:03d}:")
        for act_name, metrics_dict in results.items():
            print(f"\nActivation: {act_name}")
            for metric_name, metric_values in metrics_dict.items():
                print(f"  {metric_name}: {metric_values}")

        # Plot Accuracy
        plt.figure(figsize=(15,8))
        for key, hist_vals in results.items():
            plt.plot(hist_vals['accuracy'], label=key)
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.title('Accuracy')
        plt.legend()
        plt.grid()
        plt.show()
        # Plot Loss
        plt.figure(figsize=(15,8))
        for key, hist_vals in results.items():
            plt.plot(hist_vals['loss'], label=key)
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title('Loss')
        plt.legend()
        plt.grid()
        plt.show()

        np.savez(f"accuracy_{run_idx:03d}_{act_name}.npz", accuracy=np.array(history.history['accuracy']))
        np.savez(f"loss_{run_idx:03d}_{act_name}.npz", loss=np.array(history.history['loss']))
        
        accuracy_results[act_name] = np.array(history.history['accuracy'])
        loss_results[act_name] = np.array(history.history['loss'])

    print(f" ----- Data -------- ")
    results[act_name] = {key: np.array(val) for key, val in history.history.items()}
    print(f"Details in results for round {run_idx:03d}:")
    for act_name, metrics_dict in results.items():
        print(f"\nActivation: {act_name}")
        for metric_name, metric_values in metrics_dict.items():
            print(f"  {metric_name}: {metric_values}")

    print(f" ------------------- ")
    ###np.savez(f"accuracy_{run_idx:03d}.npz", **accuracy_results)
    ###np.savez(f"loss_{run_idx:03d}.npz", **loss_results)

folder_path = '.'
accuracy_files = sorted([f for f in os.listdir(folder_path) if re.match(r'accuracy_\d+\.npz', f)])
loss_files = sorted([f for f in os.listdir(folder_path) if re.match(r'loss_\d+\.npz', f)])

accuracy_collections = {}
for fname in accuracy_files:
    acc_data = np.load(os.path.join(folder_path, fname), allow_pickle=True)
    for key in acc_data.files:
        if key not in accuracy_collections:
            accuracy_collections[key] = []
        accuracy_collections[key].append(acc_data[key])

accuracy_avg = {}
for act_name, vals in accuracy_collections.items():
    stacked = np.vstack(vals)
    accuracy_avg[act_name] = np.mean(stacked, axis=0)

loss_collections = {}
for fname in loss_files:
    los_data = np.load(os.path.join(folder_path, fname), allow_pickle=True)
    for key in los_data.files:
        if key not in loss_collections:
            loss_collections[key] = []
        loss_collections[key].append(los_data[key])

loss_avg = {}
for act_name, vals in loss_collections.items():
    stacked = np.vstack(vals)
    loss_avg[act_name] = np.mean(stacked, axis=0)

plt.figure(figsize=(15,8))
for i, act_name in enumerate(accuracy_avg):
    plt.plot(accuracy_avg[act_name], label=act_name)
plt.xlabel('Epoch')
plt.ylabel('Average Accuracy')
plt.title('Average Accuracy of Activation Functions')
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(15,8))
for i, act_name in enumerate(loss_avg):
    plt.plot(loss_avg[act_name], label=act_name)
plt.xlabel('Epoch')
plt.ylabel('Average Loss')
plt.title('Average Loss of Activation Functions')
plt.legend()
plt.grid()
plt.show()

for i in range(len(accuracy_files)):
    fname_acc = accuracy_files[i]
    fname_loss = loss_files[i]
    print(f"\n--- Loading {fname_acc} and {fname_loss} ---")
    acc_data = np.load(os.path.join(folder_path, fname_acc), allow_pickle=True)
    loss_data = np.load(os.path.join(folder_path, fname_loss), allow_pickle=True)

    print("Keys accuracy:", list(acc_data.keys()))
    print("Keys loss:", list(loss_data.keys()))

    activation_names = list(acc_data.files)

    # Plot Accuracy
    plt.figure(figsize=(15,8))
    for name in activation_names:
        plt.plot(acc_data[name], label=name)
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title(f'Accuracy from {fname_acc}')
    plt.legend()
    plt.grid()
    plt.show()
    # Plot Loss
    plt.figure(figsize=(15,8))
    for name in activation_names:
        plt.plot(loss_data[name], label=name)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'Loss from {fname_loss}')
    plt.legend()
    plt.grid()
    plt.show()
   
print(f"\nEND at {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# --- Run 000 of 001 ---
# Running: Activation=SECHLU at 2025-08-14 23:24:43
# Epoch 1/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 78s 94ms/step - accuracy: 0.4306 - loss: 1.5677 - val_accuracy: 0.5393 - val_loss: 1.2709
# Epoch 2/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 97ms/step - accuracy: 0.6138 - loss: 1.0822 - val_accuracy: 0.6003 - val_loss: 1.1365
# Epoch 3/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 89ms/step - accuracy: 0.6731 - loss: 0.9207 - val_accuracy: 0.6415 - val_loss: 1.0369
# Epoch 4/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 89ms/step - accuracy: 0.7097 - loss: 0.8229 - val_accuracy: 0.6793 - val_loss: 0.9283
# Epoch 5/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 89ms/step - accuracy: 0.7346 - loss: 0.7577 - val_accuracy: 0.6922 - val_loss: 0.8773
# Epoch 6/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 91ms/step - accuracy: 0.7494 - loss: 0.7073 - val_accuracy: 0.7020 - val_loss: 0.8437
# Epoch 7/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.7658 - loss: 0.6635 - val_accuracy: 0.7138 - val_loss: 0.8502
# Epoch 8/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 90ms/step - accuracy: 0.7828 - loss: 0.6240 - val_accuracy: 0.7138 - val_loss: 0.8121
# Epoch 9/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.7926 - loss: 0.6043 - val_accuracy: 0.7393 - val_loss: 0.7728
# Epoch 10/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 92ms/step - accuracy: 0.7994 - loss: 0.5683 - val_accuracy: 0.7309 - val_loss: 0.7681
# Epoch 11/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.8034 - loss: 0.5572 - val_accuracy: 0.7246 - val_loss: 0.7975
# Epoch 12/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.8100 - loss: 0.5431 - val_accuracy: 0.7348 - val_loss: 0.8008
# Epoch 13/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 90ms/step - accuracy: 0.8249 - loss: 0.5042 - val_accuracy: 0.7350 - val_loss: 0.8099
# Epoch 14/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.8293 - loss: 0.4929 - val_accuracy: 0.7327 - val_loss: 0.7978
# Epoch 15/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 92ms/step - accuracy: 0.8319 - loss: 0.4815 - val_accuracy: 0.7333 - val_loss: 0.8318
# Epoch 16/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.8414 - loss: 0.4601 - val_accuracy: 0.7340 - val_loss: 0.8047
# Epoch 17/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.8415 - loss: 0.4573 - val_accuracy: 0.7443 - val_loss: 0.7811
# Epoch 18/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 93ms/step - accuracy: 0.8471 - loss: 0.4352 - val_accuracy: 0.7434 - val_loss: 0.7826
# Epoch 19/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 92ms/step - accuracy: 0.8486 - loss: 0.4309 - val_accuracy: 0.7405 - val_loss: 0.8119
# Epoch 20/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.8529 - loss: 0.4187 - val_accuracy: 0.7506 - val_loss: 0.7603
# Epoch 21/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.8599 - loss: 0.4041 - val_accuracy: 0.7390 - val_loss: 0.8217
# Epoch 22/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.8609 - loss: 0.3947 - val_accuracy: 0.7366 - val_loss: 0.8215
# Epoch 23/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 93ms/step - accuracy: 0.8618 - loss: 0.3896 - val_accuracy: 0.7463 - val_loss: 0.7972
# Epoch 24/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 92ms/step - accuracy: 0.8628 - loss: 0.3812 - val_accuracy: 0.7358 - val_loss: 0.8500
# Epoch 25/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 92ms/step - accuracy: 0.8713 - loss: 0.3699 - val_accuracy: 0.7420 - val_loss: 0.8217
# Epoch 26/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 92ms/step - accuracy: 0.8707 - loss: 0.3631 - val_accuracy: 0.7428 - val_loss: 0.8031
# Epoch 27/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 92ms/step - accuracy: 0.8712 - loss: 0.3610 - val_accuracy: 0.7378 - val_loss: 0.8268
# Epoch 28/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 93ms/step - accuracy: 0.8755 - loss: 0.3527 - val_accuracy: 0.7511 - val_loss: 0.8223
# Epoch 29/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 93ms/step - accuracy: 0.8770 - loss: 0.3432 - val_accuracy: 0.7492 - val_loss: 0.8168
# Epoch 30/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 94ms/step - accuracy: 0.8824 - loss: 0.3338 - val_accuracy: 0.7379 - val_loss: 0.8571
# Epoch 31/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 74s 95ms/step - accuracy: 0.8849 - loss: 0.3272 - val_accuracy: 0.7416 - val_loss: 0.8416
# Epoch 32/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 97ms/step - accuracy: 0.8836 - loss: 0.3287 - val_accuracy: 0.7445 - val_loss: 0.8553
# Epoch 33/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 74s 94ms/step - accuracy: 0.8905 - loss: 0.3133 - val_accuracy: 0.7517 - val_loss: 0.8489
# Epoch 34/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 74s 95ms/step - accuracy: 0.8909 - loss: 0.3052 - val_accuracy: 0.7477 - val_loss: 0.8325
# Epoch 35/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 96ms/step - accuracy: 0.8930 - loss: 0.3034 - val_accuracy: 0.7333 - val_loss: 0.8973
# Epoch 36/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 96ms/step - accuracy: 0.8923 - loss: 0.2997 - val_accuracy: 0.7450 - val_loss: 0.8716
# Epoch 37/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 74s 95ms/step - accuracy: 0.8984 - loss: 0.2936 - val_accuracy: 0.7523 - val_loss: 0.8494
# Epoch 38/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 74s 95ms/step - accuracy: 0.8959 - loss: 0.2917 - val_accuracy: 0.7421 - val_loss: 0.8727
# Epoch 39/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 95ms/step - accuracy: 0.9004 - loss: 0.2813 - val_accuracy: 0.7501 - val_loss: 0.8698
# Epoch 40/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 96ms/step - accuracy: 0.9017 - loss: 0.2819 - val_accuracy: 0.7328 - val_loss: 0.9362
# Epoch 41/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 96ms/step - accuracy: 0.9045 - loss: 0.2708 - val_accuracy: 0.7465 - val_loss: 0.8795
# Epoch 42/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 96ms/step - accuracy: 0.9038 - loss: 0.2692 - val_accuracy: 0.7419 - val_loss: 0.9000
# Epoch 43/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 77s 98ms/step - accuracy: 0.9045 - loss: 0.2716 - val_accuracy: 0.7363 - val_loss: 0.9647
# Epoch 44/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 97ms/step - accuracy: 0.9088 - loss: 0.2577 - val_accuracy: 0.7472 - val_loss: 0.9202
# Epoch 45/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 96ms/step - accuracy: 0.9060 - loss: 0.2642 - val_accuracy: 0.7393 - val_loss: 0.9336
# Epoch 46/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 96ms/step - accuracy: 0.9099 - loss: 0.2501 - val_accuracy: 0.7444 - val_loss: 0.9091
# Epoch 47/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 96ms/step - accuracy: 0.9140 - loss: 0.2433 - val_accuracy: 0.7379 - val_loss: 0.9476
# Epoch 48/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 97ms/step - accuracy: 0.9129 - loss: 0.2441 - val_accuracy: 0.7368 - val_loss: 0.9578
# Epoch 49/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 97ms/step - accuracy: 0.9136 - loss: 0.2418 - val_accuracy: 0.7435 - val_loss: 0.9151
# Epoch 50/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 78s 100ms/step - accuracy: 0.9166 - loss: 0.2365 - val_accuracy: 0.7371 - val_loss: 0.9483
# Epoch 51/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 97ms/step - accuracy: 0.9161 - loss: 0.2332 - val_accuracy: 0.7405 - val_loss: 0.9498
# Epoch 52/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 98ms/step - accuracy: 0.9174 - loss: 0.2316 - val_accuracy: 0.7425 - val_loss: 0.9582
# Epoch 53/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 97ms/step - accuracy: 0.9212 - loss: 0.2273 - val_accuracy: 0.7478 - val_loss: 0.9416
# Epoch 54/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 97ms/step - accuracy: 0.9241 - loss: 0.2172 - val_accuracy: 0.7368 - val_loss: 1.0008
# Epoch 55/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 78s 100ms/step - accuracy: 0.9234 - loss: 0.2225 - val_accuracy: 0.7483 - val_loss: 0.9527
# Epoch 56/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 77s 98ms/step - accuracy: 0.9265 - loss: 0.2090 - val_accuracy: 0.7337 - val_loss: 1.0399
# Epoch 57/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 77s 99ms/step - accuracy: 0.9253 - loss: 0.2136 - val_accuracy: 0.7438 - val_loss: 0.9700
# Epoch 58/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 77s 99ms/step - accuracy: 0.9266 - loss: 0.2108 - val_accuracy: 0.7489 - val_loss: 0.9433
# Epoch 59/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 77s 99ms/step - accuracy: 0.9319 - loss: 0.2008 - val_accuracy: 0.7429 - val_loss: 0.9759
# Epoch 60/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 98ms/step - accuracy: 0.9290 - loss: 0.2043 - val_accuracy: 0.7420 - val_loss: 0.9994
# Epoch 61/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 77s 98ms/step - accuracy: 0.9315 - loss: 0.1969 - val_accuracy: 0.7375 - val_loss: 1.0645
# Epoch 62/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 98ms/step - accuracy: 0.9313 - loss: 0.2010 - val_accuracy: 0.7420 - val_loss: 1.0183
# Epoch 63/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 78s 100ms/step - accuracy: 0.9359 - loss: 0.1901 - val_accuracy: 0.7409 - val_loss: 1.0322
# Epoch 64/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 77s 98ms/step - accuracy: 0.9348 - loss: 0.1876 - val_accuracy: 0.7348 - val_loss: 1.0330
# Epoch 65/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 77s 99ms/step - accuracy: 0.9335 - loss: 0.1909 - val_accuracy: 0.7438 - val_loss: 1.0007
# Epoch 66/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 77s 98ms/step - accuracy: 0.9329 - loss: 0.1885 - val_accuracy: 0.7435 - val_loss: 1.0049
# Epoch 67/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 78s 99ms/step - accuracy: 0.9330 - loss: 0.1910 - val_accuracy: 0.7408 - val_loss: 1.0116
# Epoch 68/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 77s 99ms/step - accuracy: 0.9387 - loss: 0.1768 - val_accuracy: 0.7435 - val_loss: 1.0506
# Epoch 69/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 78s 99ms/step - accuracy: 0.9368 - loss: 0.1802 - val_accuracy: 0.7270 - val_loss: 1.1383
# Epoch 70/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 77s 99ms/step - accuracy: 0.9386 - loss: 0.1753 - val_accuracy: 0.7396 - val_loss: 1.0745
# Epoch 71/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 78s 100ms/step - accuracy: 0.9389 - loss: 0.1738 - val_accuracy: 0.7417 - val_loss: 1.0397
# Epoch 72/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 77s 99ms/step - accuracy: 0.9393 - loss: 0.1727 - val_accuracy: 0.7237 - val_loss: 1.1292
# Epoch 73/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 78s 99ms/step - accuracy: 0.9420 - loss: 0.1676 - val_accuracy: 0.7366 - val_loss: 1.0769
# Epoch 74/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 78s 99ms/step - accuracy: 0.9417 - loss: 0.1685 - val_accuracy: 0.7377 - val_loss: 1.0771
# Epoch 75/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 79s 101ms/step - accuracy: 0.9442 - loss: 0.1628 - val_accuracy: 0.7404 - val_loss: 1.0883
# Epoch 76/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 78s 99ms/step - accuracy: 0.9425 - loss: 0.1655 - val_accuracy: 0.7446 - val_loss: 1.0565
# Epoch 77/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 78s 99ms/step - accuracy: 0.9445 - loss: 0.1588 - val_accuracy: 0.7381 - val_loss: 1.0706
# Epoch 78/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 104ms/step - accuracy: 0.9436 - loss: 0.1618 - val_accuracy: 0.7373 - val_loss: 1.1269
# Epoch 79/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 84s 107ms/step - accuracy: 0.9473 - loss: 0.1556 - val_accuracy: 0.7289 - val_loss: 1.1193
# Epoch 80/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 78s 100ms/step - accuracy: 0.9440 - loss: 0.1591 - val_accuracy: 0.7224 - val_loss: 1.1734
# Epoch 81/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 101ms/step - accuracy: 0.9451 - loss: 0.1579 - val_accuracy: 0.7412 - val_loss: 1.1201
# Epoch 82/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 80s 102ms/step - accuracy: 0.9481 - loss: 0.1526 - val_accuracy: 0.7376 - val_loss: 1.1333
# Epoch 83/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 80s 102ms/step - accuracy: 0.9445 - loss: 0.1563 - val_accuracy: 0.7290 - val_loss: 1.2136
# Epoch 84/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 80s 102ms/step - accuracy: 0.9512 - loss: 0.1442 - val_accuracy: 0.7408 - val_loss: 1.1209
# Epoch 85/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 82s 105ms/step - accuracy: 0.9496 - loss: 0.1466 - val_accuracy: 0.7274 - val_loss: 1.1712
# Epoch 86/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 109ms/step - accuracy: 0.9487 - loss: 0.1506 - val_accuracy: 0.7403 - val_loss: 1.1099
# Epoch 87/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 106ms/step - accuracy: 0.9497 - loss: 0.1463 - val_accuracy: 0.7441 - val_loss: 1.0885
# Epoch 88/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 79s 101ms/step - accuracy: 0.9529 - loss: 0.1375 - val_accuracy: 0.7356 - val_loss: 1.1294
# Epoch 89/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 79s 101ms/step - accuracy: 0.9533 - loss: 0.1376 - val_accuracy: 0.7312 - val_loss: 1.1978
# Epoch 90/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 103ms/step - accuracy: 0.9513 - loss: 0.1403 - val_accuracy: 0.7352 - val_loss: 1.1464
# Epoch 91/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 80s 102ms/step - accuracy: 0.9511 - loss: 0.1380 - val_accuracy: 0.7417 - val_loss: 1.1332
# Epoch 92/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 80s 102ms/step - accuracy: 0.9523 - loss: 0.1406 - val_accuracy: 0.7401 - val_loss: 1.1484
# Epoch 93/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 80s 102ms/step - accuracy: 0.9524 - loss: 0.1381 - val_accuracy: 0.7367 - val_loss: 1.1848
# Epoch 94/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 103ms/step - accuracy: 0.9533 - loss: 0.1341 - val_accuracy: 0.7343 - val_loss: 1.2071
# Epoch 95/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 80s 102ms/step - accuracy: 0.9547 - loss: 0.1320 - val_accuracy: 0.7402 - val_loss: 1.1751
# Epoch 96/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 80s 103ms/step - accuracy: 0.9558 - loss: 0.1290 - val_accuracy: 0.7372 - val_loss: 1.1683
# Epoch 97/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 103ms/step - accuracy: 0.9540 - loss: 0.1311 - val_accuracy: 0.7352 - val_loss: 1.1963
# Epoch 98/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 80s 103ms/step - accuracy: 0.9557 - loss: 0.1288 - val_accuracy: 0.7290 - val_loss: 1.1844
# Epoch 99/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 80s 103ms/step - accuracy: 0.9554 - loss: 0.1268 - val_accuracy: 0.7381 - val_loss: 1.2154
# Epoch 100/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 80s 103ms/step - accuracy: 0.9570 - loss: 0.1263 - val_accuracy: 0.7398 - val_loss: 1.1817
# Epoch 101/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.9572 - loss: 0.1230 - val_accuracy: 0.7369 - val_loss: 1.1949
# Epoch 102/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 82s 105ms/step - accuracy: 0.9607 - loss: 0.1182 - val_accuracy: 0.7268 - val_loss: 1.2089
# Epoch 103/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 103ms/step - accuracy: 0.9551 - loss: 0.1264 - val_accuracy: 0.7391 - val_loss: 1.1841
# Epoch 104/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 104ms/step - accuracy: 0.9592 - loss: 0.1196 - val_accuracy: 0.7401 - val_loss: 1.1868
# Epoch 105/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 82s 105ms/step - accuracy: 0.9562 - loss: 0.1251 - val_accuracy: 0.7352 - val_loss: 1.2107
# Epoch 106/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 107ms/step - accuracy: 0.9609 - loss: 0.1162 - val_accuracy: 0.7331 - val_loss: 1.2241
# Epoch 107/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 104ms/step - accuracy: 0.9596 - loss: 0.1183 - val_accuracy: 0.7227 - val_loss: 1.2551
# Epoch 108/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 109ms/step - accuracy: 0.9596 - loss: 0.1160 - val_accuracy: 0.7378 - val_loss: 1.2122
# Epoch 109/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 82s 105ms/step - accuracy: 0.9593 - loss: 0.1166 - val_accuracy: 0.7391 - val_loss: 1.2198
# Epoch 110/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 106ms/step - accuracy: 0.9605 - loss: 0.1152 - val_accuracy: 0.7392 - val_loss: 1.2506
# Epoch 111/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 84s 107ms/step - accuracy: 0.9583 - loss: 0.1183 - val_accuracy: 0.7371 - val_loss: 1.2425
# Epoch 112/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 106ms/step - accuracy: 0.9627 - loss: 0.1111 - val_accuracy: 0.7416 - val_loss: 1.2323
# Epoch 113/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 82s 105ms/step - accuracy: 0.9601 - loss: 0.1160 - val_accuracy: 0.7309 - val_loss: 1.2660
# Epoch 114/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 82s 105ms/step - accuracy: 0.9637 - loss: 0.1086 - val_accuracy: 0.7335 - val_loss: 1.2570
# Epoch 115/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 106ms/step - accuracy: 0.9633 - loss: 0.1089 - val_accuracy: 0.7391 - val_loss: 1.2767
# Epoch 116/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 106ms/step - accuracy: 0.9653 - loss: 0.1032 - val_accuracy: 0.7382 - val_loss: 1.2596
# Epoch 117/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 106ms/step - accuracy: 0.9647 - loss: 0.1049 - val_accuracy: 0.7189 - val_loss: 1.3370
# Epoch 118/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 82s 105ms/step - accuracy: 0.9602 - loss: 0.1106 - val_accuracy: 0.7397 - val_loss: 1.2500
# Epoch 119/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 106ms/step - accuracy: 0.9653 - loss: 0.1045 - val_accuracy: 0.7413 - val_loss: 1.2592
# Epoch 120/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 106ms/step - accuracy: 0.9632 - loss: 0.1038 - val_accuracy: 0.7357 - val_loss: 1.2877
# Epoch 121/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 106ms/step - accuracy: 0.9643 - loss: 0.1059 - val_accuracy: 0.7285 - val_loss: 1.3016
# Epoch 122/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 106ms/step - accuracy: 0.9628 - loss: 0.1060 - val_accuracy: 0.7285 - val_loss: 1.3022
# Epoch 123/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 109ms/step - accuracy: 0.9652 - loss: 0.1028 - val_accuracy: 0.7367 - val_loss: 1.2678
# Epoch 124/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 107ms/step - accuracy: 0.9658 - loss: 0.1029 - val_accuracy: 0.7370 - val_loss: 1.2855
# Epoch 125/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 106ms/step - accuracy: 0.9681 - loss: 0.0956 - val_accuracy: 0.7361 - val_loss: 1.2876
# Epoch 126/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 84s 108ms/step - accuracy: 0.9625 - loss: 0.1067 - val_accuracy: 0.7375 - val_loss: 1.2763
# Epoch 127/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 107ms/step - accuracy: 0.9645 - loss: 0.1037 - val_accuracy: 0.7434 - val_loss: 1.2760
# Epoch 128/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 84s 107ms/step - accuracy: 0.9624 - loss: 0.1052 - val_accuracy: 0.7396 - val_loss: 1.3100
# Epoch 129/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 84s 107ms/step - accuracy: 0.9683 - loss: 0.0941 - val_accuracy: 0.7426 - val_loss: 1.2695
# Epoch 130/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 108ms/step - accuracy: 0.9660 - loss: 0.1012 - val_accuracy: 0.7344 - val_loss: 1.3181
# Epoch 131/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 84s 107ms/step - accuracy: 0.9675 - loss: 0.0974 - val_accuracy: 0.7367 - val_loss: 1.3044
# Epoch 132/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 84s 107ms/step - accuracy: 0.9698 - loss: 0.0901 - val_accuracy: 0.7373 - val_loss: 1.2843
# Epoch 133/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 108ms/step - accuracy: 0.9672 - loss: 0.0975 - val_accuracy: 0.7393 - val_loss: 1.2744
# Epoch 134/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 108ms/step - accuracy: 0.9686 - loss: 0.0944 - val_accuracy: 0.7396 - val_loss: 1.2970
# Epoch 135/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 108ms/step - accuracy: 0.9666 - loss: 0.0994 - val_accuracy: 0.7253 - val_loss: 1.3464
# Epoch 136/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 108ms/step - accuracy: 0.9686 - loss: 0.0907 - val_accuracy: 0.7387 - val_loss: 1.3154
# Epoch 137/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 109ms/step - accuracy: 0.9679 - loss: 0.0928 - val_accuracy: 0.7296 - val_loss: 1.3503
# Epoch 138/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 108ms/step - accuracy: 0.9677 - loss: 0.0947 - val_accuracy: 0.7355 - val_loss: 1.3041
# Epoch 139/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 86s 109ms/step - accuracy: 0.9676 - loss: 0.0961 - val_accuracy: 0.7310 - val_loss: 1.3542
# Epoch 140/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 109ms/step - accuracy: 0.9715 - loss: 0.0861 - val_accuracy: 0.7388 - val_loss: 1.3184
# Epoch 141/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 109ms/step - accuracy: 0.9698 - loss: 0.0874 - val_accuracy: 0.7415 - val_loss: 1.3368
# Epoch 142/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 84s 108ms/step - accuracy: 0.9699 - loss: 0.0878 - val_accuracy: 0.7466 - val_loss: 1.3113
# Epoch 143/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 108ms/step - accuracy: 0.9702 - loss: 0.0875 - val_accuracy: 0.7321 - val_loss: 1.3584
# Epoch 144/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 86s 110ms/step - accuracy: 0.9681 - loss: 0.0919 - val_accuracy: 0.7428 - val_loss: 1.3325
# Epoch 145/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 109ms/step - accuracy: 0.9720 - loss: 0.0842 - val_accuracy: 0.7430 - val_loss: 1.3427
# Epoch 146/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 109ms/step - accuracy: 0.9708 - loss: 0.0862 - val_accuracy: 0.7337 - val_loss: 1.3737
# Epoch 147/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 86s 110ms/step - accuracy: 0.9716 - loss: 0.0848 - val_accuracy: 0.7413 - val_loss: 1.3406
# Epoch 148/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 86s 110ms/step - accuracy: 0.9718 - loss: 0.0858 - val_accuracy: 0.7354 - val_loss: 1.3665
# Epoch 149/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 90s 114ms/step - accuracy: 0.9716 - loss: 0.0860 - val_accuracy: 0.7376 - val_loss: 1.3700
# Epoch 150/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 89s 114ms/step - accuracy: 0.9715 - loss: 0.0839 - val_accuracy: 0.7296 - val_loss: 1.4348
# Epoch 151/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.9692 - loss: 0.0898 - val_accuracy: 0.7305 - val_loss: 1.4252
# Epoch 152/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 86s 109ms/step - accuracy: 0.9715 - loss: 0.0840 - val_accuracy: 0.7365 - val_loss: 1.3664
# Epoch 153/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 86s 109ms/step - accuracy: 0.9702 - loss: 0.0872 - val_accuracy: 0.7377 - val_loss: 1.3592
# Epoch 154/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.9722 - loss: 0.0825 - val_accuracy: 0.7336 - val_loss: 1.4411
# Epoch 155/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 86s 110ms/step - accuracy: 0.9711 - loss: 0.0847 - val_accuracy: 0.7361 - val_loss: 1.3638
# Epoch 156/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.9751 - loss: 0.0762 - val_accuracy: 0.7299 - val_loss: 1.4443
# Epoch 157/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 86s 110ms/step - accuracy: 0.9694 - loss: 0.0874 - val_accuracy: 0.7387 - val_loss: 1.3625
# Epoch 158/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 112ms/step - accuracy: 0.9747 - loss: 0.0738 - val_accuracy: 0.7378 - val_loss: 1.3670
# Epoch 159/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.9712 - loss: 0.0846 - val_accuracy: 0.7324 - val_loss: 1.4073
# Epoch 160/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.9703 - loss: 0.0843 - val_accuracy: 0.7304 - val_loss: 1.3969
# Epoch 161/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 112ms/step - accuracy: 0.9728 - loss: 0.0802 - val_accuracy: 0.7431 - val_loss: 1.3599
# Epoch 162/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.9768 - loss: 0.0714 - val_accuracy: 0.7396 - val_loss: 1.4022
# Epoch 163/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.9727 - loss: 0.0790 - val_accuracy: 0.7402 - val_loss: 1.3972
# Epoch 164/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.9736 - loss: 0.0775 - val_accuracy: 0.7415 - val_loss: 1.3890
# Epoch 165/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 89s 113ms/step - accuracy: 0.9746 - loss: 0.0764 - val_accuracy: 0.7370 - val_loss: 1.4243
# Epoch 166/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.9751 - loss: 0.0758 - val_accuracy: 0.7324 - val_loss: 1.4472
# Epoch 167/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.9747 - loss: 0.0756 - val_accuracy: 0.7395 - val_loss: 1.4276
# Epoch 168/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 88s 113ms/step - accuracy: 0.9738 - loss: 0.0757 - val_accuracy: 0.7334 - val_loss: 1.4426
# Epoch 169/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 88s 112ms/step - accuracy: 0.9780 - loss: 0.0702 - val_accuracy: 0.7398 - val_loss: 1.4062
# Epoch 170/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 88s 113ms/step - accuracy: 0.9746 - loss: 0.0755 - val_accuracy: 0.7361 - val_loss: 1.4144
# Epoch 171/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 88s 112ms/step - accuracy: 0.9720 - loss: 0.0796 - val_accuracy: 0.7366 - val_loss: 1.4569
# Epoch 172/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 89s 114ms/step - accuracy: 0.9740 - loss: 0.0760 - val_accuracy: 0.7363 - val_loss: 1.4389
# Epoch 173/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 88s 113ms/step - accuracy: 0.9764 - loss: 0.0721 - val_accuracy: 0.7348 - val_loss: 1.4400
# Epoch 174/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 88s 113ms/step - accuracy: 0.9756 - loss: 0.0717 - val_accuracy: 0.7340 - val_loss: 1.4484
# Epoch 175/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 89s 113ms/step - accuracy: 0.9740 - loss: 0.0737 - val_accuracy: 0.7308 - val_loss: 1.4904
# Epoch 176/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 88s 113ms/step - accuracy: 0.9738 - loss: 0.0769 - val_accuracy: 0.7399 - val_loss: 1.4485
# Epoch 177/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 88s 113ms/step - accuracy: 0.9759 - loss: 0.0713 - val_accuracy: 0.7409 - val_loss: 1.4387
# Epoch 178/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 89s 114ms/step - accuracy: 0.9777 - loss: 0.0701 - val_accuracy: 0.7453 - val_loss: 1.4181
# Epoch 179/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 89s 113ms/step - accuracy: 0.9774 - loss: 0.0690 - val_accuracy: 0.7387 - val_loss: 1.4537
# Epoch 180/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 89s 113ms/step - accuracy: 0.9762 - loss: 0.0721 - val_accuracy: 0.7321 - val_loss: 1.4619
# Epoch 181/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 89s 113ms/step - accuracy: 0.9789 - loss: 0.0660 - val_accuracy: 0.7411 - val_loss: 1.4597
# Epoch 182/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 89s 114ms/step - accuracy: 0.9746 - loss: 0.0735 - val_accuracy: 0.7356 - val_loss: 1.4682
# Epoch 183/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 89s 113ms/step - accuracy: 0.9756 - loss: 0.0701 - val_accuracy: 0.7342 - val_loss: 1.4790
# Epoch 184/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 89s 114ms/step - accuracy: 0.9761 - loss: 0.0703 - val_accuracy: 0.7383 - val_loss: 1.4500
# Epoch 185/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 116ms/step - accuracy: 0.9787 - loss: 0.0629 - val_accuracy: 0.7316 - val_loss: 1.5211
# Epoch 186/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 89s 114ms/step - accuracy: 0.9737 - loss: 0.0764 - val_accuracy: 0.7371 - val_loss: 1.4765
# Epoch 187/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 89s 114ms/step - accuracy: 0.9769 - loss: 0.0686 - val_accuracy: 0.7377 - val_loss: 1.5105
# Epoch 188/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 90s 115ms/step - accuracy: 0.9754 - loss: 0.0722 - val_accuracy: 0.7330 - val_loss: 1.4712
# Epoch 189/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 90s 115ms/step - accuracy: 0.9768 - loss: 0.0681 - val_accuracy: 0.7338 - val_loss: 1.4716
# Epoch 190/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 90s 115ms/step - accuracy: 0.9747 - loss: 0.0716 - val_accuracy: 0.7399 - val_loss: 1.4852
# Epoch 191/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 90s 115ms/step - accuracy: 0.9780 - loss: 0.0674 - val_accuracy: 0.7356 - val_loss: 1.5019
# Epoch 192/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 90s 116ms/step - accuracy: 0.9746 - loss: 0.0719 - val_accuracy: 0.7443 - val_loss: 1.4278
# Epoch 193/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 90s 114ms/step - accuracy: 0.9760 - loss: 0.0695 - val_accuracy: 0.7409 - val_loss: 1.5059
# Epoch 194/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 90s 115ms/step - accuracy: 0.9757 - loss: 0.0709 - val_accuracy: 0.7318 - val_loss: 1.4918
# Epoch 195/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 116ms/step - accuracy: 0.9778 - loss: 0.0655 - val_accuracy: 0.7357 - val_loss: 1.4849
# Epoch 196/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 90s 115ms/step - accuracy: 0.9784 - loss: 0.0656 - val_accuracy: 0.7364 - val_loss: 1.4799
# Epoch 197/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 90s 115ms/step - accuracy: 0.9731 - loss: 0.0737 - val_accuracy: 0.7370 - val_loss: 1.4757
# Epoch 198/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 117ms/step - accuracy: 0.9797 - loss: 0.0615 - val_accuracy: 0.7336 - val_loss: 1.5242
# Epoch 199/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 90s 115ms/step - accuracy: 0.9776 - loss: 0.0670 - val_accuracy: 0.7414 - val_loss: 1.5072
# Epoch 200/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 90s 116ms/step - accuracy: 0.9784 - loss: 0.0655 - val_accuracy: 0.7454 - val_loss: 1.5049
# Epoch 201/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 116ms/step - accuracy: 0.9797 - loss: 0.0606 - val_accuracy: 0.7356 - val_loss: 1.5049
# Epoch 202/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 116ms/step - accuracy: 0.9754 - loss: 0.0701 - val_accuracy: 0.7396 - val_loss: 1.4844
# Epoch 203/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 90s 115ms/step - accuracy: 0.9781 - loss: 0.0668 - val_accuracy: 0.7380 - val_loss: 1.5125
# Epoch 204/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 116ms/step - accuracy: 0.9785 - loss: 0.0612 - val_accuracy: 0.7375 - val_loss: 1.5122
# Epoch 205/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9780 - loss: 0.0647 - val_accuracy: 0.7422 - val_loss: 1.5117
# Epoch 206/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 117ms/step - accuracy: 0.9788 - loss: 0.0637 - val_accuracy: 0.7382 - val_loss: 1.5154
# Epoch 207/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 116ms/step - accuracy: 0.9813 - loss: 0.0582 - val_accuracy: 0.7346 - val_loss: 1.5426
# Epoch 208/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 117ms/step - accuracy: 0.9769 - loss: 0.0661 - val_accuracy: 0.7333 - val_loss: 1.5522
# Epoch 209/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 117ms/step - accuracy: 0.9784 - loss: 0.0637 - val_accuracy: 0.7326 - val_loss: 1.5520
# Epoch 210/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 116ms/step - accuracy: 0.9785 - loss: 0.0644 - val_accuracy: 0.7324 - val_loss: 1.5410
# Epoch 211/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 117ms/step - accuracy: 0.9790 - loss: 0.0612 - val_accuracy: 0.7409 - val_loss: 1.5170
# Epoch 212/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9788 - loss: 0.0616 - val_accuracy: 0.7379 - val_loss: 1.5277
# Epoch 213/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 117ms/step - accuracy: 0.9756 - loss: 0.0700 - val_accuracy: 0.7344 - val_loss: 1.5145
# Epoch 214/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 117ms/step - accuracy: 0.9792 - loss: 0.0634 - val_accuracy: 0.7393 - val_loss: 1.5398
# Epoch 215/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 117ms/step - accuracy: 0.9773 - loss: 0.0665 - val_accuracy: 0.7347 - val_loss: 1.5802
# Epoch 216/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 117ms/step - accuracy: 0.9799 - loss: 0.0614 - val_accuracy: 0.7331 - val_loss: 1.6357
# Epoch 217/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 116ms/step - accuracy: 0.9805 - loss: 0.0601 - val_accuracy: 0.7348 - val_loss: 1.5738
# Epoch 218/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 118ms/step - accuracy: 0.9803 - loss: 0.0592 - val_accuracy: 0.7295 - val_loss: 1.5558
# Epoch 219/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 117ms/step - accuracy: 0.9787 - loss: 0.0624 - val_accuracy: 0.7357 - val_loss: 1.5441
# Epoch 220/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 117ms/step - accuracy: 0.9765 - loss: 0.0665 - val_accuracy: 0.7359 - val_loss: 1.5851
# Epoch 221/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 118ms/step - accuracy: 0.9797 - loss: 0.0598 - val_accuracy: 0.7326 - val_loss: 1.6501
# Epoch 222/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 117ms/step - accuracy: 0.9808 - loss: 0.0576 - val_accuracy: 0.7379 - val_loss: 1.5957
# Epoch 223/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 117ms/step - accuracy: 0.9800 - loss: 0.0595 - val_accuracy: 0.7345 - val_loss: 1.5727
# Epoch 224/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 117ms/step - accuracy: 0.9791 - loss: 0.0596 - val_accuracy: 0.7370 - val_loss: 1.5453
# Epoch 225/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 118ms/step - accuracy: 0.9805 - loss: 0.0588 - val_accuracy: 0.7356 - val_loss: 1.5523
# Epoch 226/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 117ms/step - accuracy: 0.9765 - loss: 0.0640 - val_accuracy: 0.7438 - val_loss: 1.5279
# Epoch 227/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 118ms/step - accuracy: 0.9816 - loss: 0.0556 - val_accuracy: 0.7373 - val_loss: 1.5808
# Epoch 228/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 118ms/step - accuracy: 0.9789 - loss: 0.0605 - val_accuracy: 0.7383 - val_loss: 1.6061
# Epoch 229/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 118ms/step - accuracy: 0.9815 - loss: 0.0546 - val_accuracy: 0.7357 - val_loss: 1.5963
# Epoch 230/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 117ms/step - accuracy: 0.9795 - loss: 0.0597 - val_accuracy: 0.7343 - val_loss: 1.6162
# Epoch 231/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9810 - loss: 0.0554 - val_accuracy: 0.7392 - val_loss: 1.5743
# Epoch 232/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 118ms/step - accuracy: 0.9821 - loss: 0.0535 - val_accuracy: 0.7356 - val_loss: 1.5932
# Epoch 233/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 118ms/step - accuracy: 0.9816 - loss: 0.0559 - val_accuracy: 0.7364 - val_loss: 1.5834
# Epoch 234/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9834 - loss: 0.0531 - val_accuracy: 0.7341 - val_loss: 1.6017
# Epoch 235/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 118ms/step - accuracy: 0.9817 - loss: 0.0544 - val_accuracy: 0.7366 - val_loss: 1.6034
# Epoch 236/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 118ms/step - accuracy: 0.9801 - loss: 0.0580 - val_accuracy: 0.7326 - val_loss: 1.6282
# Epoch 237/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 118ms/step - accuracy: 0.9819 - loss: 0.0542 - val_accuracy: 0.7394 - val_loss: 1.5698
# Epoch 238/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9786 - loss: 0.0623 - val_accuracy: 0.7432 - val_loss: 1.5777
# Epoch 239/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9819 - loss: 0.0538 - val_accuracy: 0.7348 - val_loss: 1.5870
# Epoch 240/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 118ms/step - accuracy: 0.9818 - loss: 0.0561 - val_accuracy: 0.7411 - val_loss: 1.5815
# Epoch 241/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9789 - loss: 0.0598 - val_accuracy: 0.7388 - val_loss: 1.6089
# Epoch 242/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 118ms/step - accuracy: 0.9810 - loss: 0.0561 - val_accuracy: 0.7426 - val_loss: 1.5820
# Epoch 243/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9797 - loss: 0.0585 - val_accuracy: 0.7420 - val_loss: 1.5683
# Epoch 244/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9820 - loss: 0.0532 - val_accuracy: 0.7344 - val_loss: 1.6079
# Epoch 245/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9796 - loss: 0.0587 - val_accuracy: 0.7351 - val_loss: 1.6236
# Epoch 246/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9841 - loss: 0.0488 - val_accuracy: 0.7327 - val_loss: 1.6569
# Epoch 247/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9798 - loss: 0.0584 - val_accuracy: 0.7364 - val_loss: 1.6306
# Epoch 248/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9824 - loss: 0.0540 - val_accuracy: 0.7432 - val_loss: 1.6167
# Epoch 249/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9786 - loss: 0.0614 - val_accuracy: 0.7425 - val_loss: 1.5881
# Epoch 250/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9851 - loss: 0.0463 - val_accuracy: 0.7392 - val_loss: 1.6284
# Epoch 251/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 121ms/step - accuracy: 0.9795 - loss: 0.0596 - val_accuracy: 0.7377 - val_loss: 1.6319
# Epoch 252/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9805 - loss: 0.0569 - val_accuracy: 0.7403 - val_loss: 1.6115
# Epoch 253/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9801 - loss: 0.0561 - val_accuracy: 0.7391 - val_loss: 1.6017
# Epoch 254/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9838 - loss: 0.0510 - val_accuracy: 0.7367 - val_loss: 1.6147
# Epoch 255/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9807 - loss: 0.0555 - val_accuracy: 0.7391 - val_loss: 1.6100
# Epoch 256/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9841 - loss: 0.0502 - val_accuracy: 0.7342 - val_loss: 1.6195
# Epoch 257/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 121ms/step - accuracy: 0.9809 - loss: 0.0547 - val_accuracy: 0.7360 - val_loss: 1.6361
# Epoch 258/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9821 - loss: 0.0532 - val_accuracy: 0.7401 - val_loss: 1.6141
# Epoch 259/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9817 - loss: 0.0542 - val_accuracy: 0.7357 - val_loss: 1.6300
# Epoch 260/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 121ms/step - accuracy: 0.9833 - loss: 0.0505 - val_accuracy: 0.7408 - val_loss: 1.6134
# Epoch 261/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9818 - loss: 0.0538 - val_accuracy: 0.7395 - val_loss: 1.6462
# Epoch 262/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 121ms/step - accuracy: 0.9854 - loss: 0.0457 - val_accuracy: 0.7419 - val_loss: 1.6511
# Epoch 263/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 121ms/step - accuracy: 0.9821 - loss: 0.0526 - val_accuracy: 0.7378 - val_loss: 1.6617
# Epoch 264/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 117ms/step - accuracy: 0.9831 - loss: 0.0512 - val_accuracy: 0.7304 - val_loss: 1.7035
# Epoch 265/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 121ms/step - accuracy: 0.9828 - loss: 0.0508 - val_accuracy: 0.7389 - val_loss: 1.6997
# Epoch 266/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 117ms/step - accuracy: 0.9820 - loss: 0.0543 - val_accuracy: 0.7379 - val_loss: 1.6601
# Epoch 267/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 118ms/step - accuracy: 0.9834 - loss: 0.0475 - val_accuracy: 0.7357 - val_loss: 1.6575
# Epoch 268/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 117ms/step - accuracy: 0.9829 - loss: 0.0469 - val_accuracy: 0.7360 - val_loss: 1.6852
# Epoch 269/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 117ms/step - accuracy: 0.9821 - loss: 0.0529 - val_accuracy: 0.7367 - val_loss: 1.6801
# Epoch 270/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 118ms/step - accuracy: 0.9842 - loss: 0.0480 - val_accuracy: 0.7342 - val_loss: 1.6785
# Epoch 271/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 117ms/step - accuracy: 0.9815 - loss: 0.0541 - val_accuracy: 0.7343 - val_loss: 1.7294
# Epoch 272/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 117ms/step - accuracy: 0.9815 - loss: 0.0529 - val_accuracy: 0.7364 - val_loss: 1.6962
# Epoch 273/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9814 - loss: 0.0550 - val_accuracy: 0.7395 - val_loss: 1.6730
# Epoch 274/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 117ms/step - accuracy: 0.9815 - loss: 0.0528 - val_accuracy: 0.7396 - val_loss: 1.6745
# Epoch 275/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 117ms/step - accuracy: 0.9835 - loss: 0.0495 - val_accuracy: 0.7377 - val_loss: 1.6740
# Epoch 276/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 117ms/step - accuracy: 0.9830 - loss: 0.0512 - val_accuracy: 0.7363 - val_loss: 1.6663
# Epoch 277/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 117ms/step - accuracy: 0.9832 - loss: 0.0492 - val_accuracy: 0.7414 - val_loss: 1.6594
# Epoch 278/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 118ms/step - accuracy: 0.9839 - loss: 0.0483 - val_accuracy: 0.7357 - val_loss: 1.6867
# Epoch 279/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 117ms/step - accuracy: 0.9836 - loss: 0.0486 - val_accuracy: 0.7340 - val_loss: 1.6615
# Epoch 280/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9816 - loss: 0.0563 - val_accuracy: 0.7383 - val_loss: 1.6875
# Epoch 281/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 118ms/step - accuracy: 0.9836 - loss: 0.0495 - val_accuracy: 0.7382 - val_loss: 1.6453
# Epoch 282/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 118ms/step - accuracy: 0.9832 - loss: 0.0506 - val_accuracy: 0.7387 - val_loss: 1.6463
# Epoch 283/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9865 - loss: 0.0409 - val_accuracy: 0.7439 - val_loss: 1.6816
# Epoch 284/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 118ms/step - accuracy: 0.9838 - loss: 0.0486 - val_accuracy: 0.7335 - val_loss: 1.6995
# Epoch 285/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 118ms/step - accuracy: 0.9846 - loss: 0.0460 - val_accuracy: 0.7371 - val_loss: 1.6739
# Epoch 286/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 118ms/step - accuracy: 0.9827 - loss: 0.0506 - val_accuracy: 0.7382 - val_loss: 1.6738
# Epoch 287/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 118ms/step - accuracy: 0.9845 - loss: 0.0469 - val_accuracy: 0.7426 - val_loss: 1.6583
# Epoch 288/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 92s 118ms/step - accuracy: 0.9820 - loss: 0.0521 - val_accuracy: 0.7379 - val_loss: 1.6858
# Epoch 289/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9856 - loss: 0.0449 - val_accuracy: 0.7409 - val_loss: 1.7168
# Epoch 290/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9854 - loss: 0.0457 - val_accuracy: 0.7416 - val_loss: 1.7057
# Epoch 291/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9844 - loss: 0.0469 - val_accuracy: 0.7319 - val_loss: 1.7399
# Epoch 292/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 118ms/step - accuracy: 0.9834 - loss: 0.0486 - val_accuracy: 0.7395 - val_loss: 1.6966
# Epoch 293/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9844 - loss: 0.0461 - val_accuracy: 0.7422 - val_loss: 1.6721
# Epoch 294/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9853 - loss: 0.0456 - val_accuracy: 0.7360 - val_loss: 1.7127
# Epoch 295/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9837 - loss: 0.0475 - val_accuracy: 0.7379 - val_loss: 1.6940
# Epoch 296/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9852 - loss: 0.0438 - val_accuracy: 0.7276 - val_loss: 1.7607
# Epoch 297/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9837 - loss: 0.0480 - val_accuracy: 0.7393 - val_loss: 1.7257
# Epoch 298/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9851 - loss: 0.0433 - val_accuracy: 0.7379 - val_loss: 1.7129
# Epoch 299/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9837 - loss: 0.0471 - val_accuracy: 0.7385 - val_loss: 1.6944
# Epoch 300/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9857 - loss: 0.0448 - val_accuracy: 0.7398 - val_loss: 1.6937
# Epoch 301/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.9850 - loss: 0.0456 - val_accuracy: 0.7373 - val_loss: 1.7134
# Epoch 302/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 121ms/step - accuracy: 0.9848 - loss: 0.0433 - val_accuracy: 0.7432 - val_loss: 1.6906
# Epoch 303/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9842 - loss: 0.0450 - val_accuracy: 0.7419 - val_loss: 1.7299
# Epoch 304/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9832 - loss: 0.0492 - val_accuracy: 0.7343 - val_loss: 1.7232
# Epoch 305/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 121ms/step - accuracy: 0.9846 - loss: 0.0455 - val_accuracy: 0.7403 - val_loss: 1.7086
# Epoch 306/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9847 - loss: 0.0452 - val_accuracy: 0.7410 - val_loss: 1.7486
# Epoch 307/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 121ms/step - accuracy: 0.9825 - loss: 0.0504 - val_accuracy: 0.7431 - val_loss: 1.7323
# Epoch 308/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9848 - loss: 0.0453 - val_accuracy: 0.7365 - val_loss: 1.7538
# Epoch 309/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 121ms/step - accuracy: 0.9874 - loss: 0.0392 - val_accuracy: 0.7353 - val_loss: 1.7157
# Epoch 310/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.9831 - loss: 0.0479 - val_accuracy: 0.7388 - val_loss: 1.7257
# Epoch 311/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 121ms/step - accuracy: 0.9861 - loss: 0.0442 - val_accuracy: 0.7410 - val_loss: 1.7379
# Epoch 312/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 121ms/step - accuracy: 0.9878 - loss: 0.0376 - val_accuracy: 0.7354 - val_loss: 1.7666
# Epoch 313/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 121ms/step - accuracy: 0.9819 - loss: 0.0507 - val_accuracy: 0.7450 - val_loss: 1.7003
# Epoch 314/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 121ms/step - accuracy: 0.9846 - loss: 0.0457 - val_accuracy: 0.7385 - val_loss: 1.7029
# Epoch 315/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 122ms/step - accuracy: 0.9856 - loss: 0.0420 - val_accuracy: 0.7339 - val_loss: 1.7681
# Epoch 316/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 121ms/step - accuracy: 0.9856 - loss: 0.0445 - val_accuracy: 0.7279 - val_loss: 1.8028
# Epoch 317/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 121ms/step - accuracy: 0.9859 - loss: 0.0421 - val_accuracy: 0.7395 - val_loss: 1.7492
# Epoch 318/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 122ms/step - accuracy: 0.9858 - loss: 0.0425 - val_accuracy: 0.7410 - val_loss: 1.7189
# Epoch 319/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 121ms/step - accuracy: 0.9864 - loss: 0.0410 - val_accuracy: 0.7368 - val_loss: 1.7599
# Epoch 320/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 122ms/step - accuracy: 0.9829 - loss: 0.0507 - val_accuracy: 0.7389 - val_loss: 1.7438
# Epoch 321/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 122ms/step - accuracy: 0.9859 - loss: 0.0410 - val_accuracy: 0.7454 - val_loss: 1.7178
# Epoch 322/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 123ms/step - accuracy: 0.9883 - loss: 0.0370 - val_accuracy: 0.7365 - val_loss: 1.7649
# Epoch 323/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 121ms/step - accuracy: 0.9826 - loss: 0.0501 - val_accuracy: 0.7396 - val_loss: 1.6999
# Epoch 324/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 122ms/step - accuracy: 0.9850 - loss: 0.0433 - val_accuracy: 0.7351 - val_loss: 1.7483
# Epoch 325/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 122ms/step - accuracy: 0.9872 - loss: 0.0391 - val_accuracy: 0.7356 - val_loss: 1.7400
# Epoch 326/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 122ms/step - accuracy: 0.9867 - loss: 0.0408 - val_accuracy: 0.7362 - val_loss: 1.7835
# Epoch 327/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 122ms/step - accuracy: 0.9861 - loss: 0.0422 - val_accuracy: 0.7365 - val_loss: 1.7504
# Epoch 328/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.9858 - loss: 0.0415 - val_accuracy: 0.7330 - val_loss: 1.7735
# Epoch 329/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 122ms/step - accuracy: 0.9850 - loss: 0.0460 - val_accuracy: 0.7327 - val_loss: 1.8172
# Epoch 330/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 121ms/step - accuracy: 0.9859 - loss: 0.0412 - val_accuracy: 0.7369 - val_loss: 1.7740
# Epoch 331/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 122ms/step - accuracy: 0.9864 - loss: 0.0405 - val_accuracy: 0.7316 - val_loss: 1.7836
# Epoch 332/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 121ms/step - accuracy: 0.9867 - loss: 0.0408 - val_accuracy: 0.7365 - val_loss: 1.7796
# Epoch 333/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 121ms/step - accuracy: 0.9828 - loss: 0.0502 - val_accuracy: 0.7414 - val_loss: 1.7807
# Epoch 334/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 123ms/step - accuracy: 0.9859 - loss: 0.0434 - val_accuracy: 0.7411 - val_loss: 1.8134
# Epoch 335/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.9831 - loss: 0.0489 - val_accuracy: 0.7354 - val_loss: 1.8043
# Epoch 336/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 122ms/step - accuracy: 0.9846 - loss: 0.0439 - val_accuracy: 0.7345 - val_loss: 1.7605
# Epoch 337/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 123ms/step - accuracy: 0.9875 - loss: 0.0385 - val_accuracy: 0.7392 - val_loss: 1.7881
# Epoch 338/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 122ms/step - accuracy: 0.9857 - loss: 0.0423 - val_accuracy: 0.7305 - val_loss: 1.7705
# Epoch 339/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 122ms/step - accuracy: 0.9850 - loss: 0.0442 - val_accuracy: 0.7338 - val_loss: 1.7636
# Epoch 340/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 100s 128ms/step - accuracy: 0.9876 - loss: 0.0386 - val_accuracy: 0.7345 - val_loss: 1.7693
# Epoch 341/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 122ms/step - accuracy: 0.9870 - loss: 0.0397 - val_accuracy: 0.7385 - val_loss: 1.8056
# Epoch 342/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 122ms/step - accuracy: 0.9849 - loss: 0.0420 - val_accuracy: 0.7357 - val_loss: 1.8048
# Epoch 343/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 124ms/step - accuracy: 0.9849 - loss: 0.0441 - val_accuracy: 0.7392 - val_loss: 1.8012
# Epoch 344/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 122ms/step - accuracy: 0.9859 - loss: 0.0428 - val_accuracy: 0.7384 - val_loss: 1.8061
# Epoch 345/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 155s 138ms/step - accuracy: 0.9852 - loss: 0.0430 - val_accuracy: 0.7416 - val_loss: 1.7759
# Epoch 346/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 132ms/step - accuracy: 0.9866 - loss: 0.0413 - val_accuracy: 0.7376 - val_loss: 1.7864
# Epoch 347/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 99s 127ms/step - accuracy: 0.9864 - loss: 0.0428 - val_accuracy: 0.7388 - val_loss: 1.7895
# Epoch 348/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 98s 126ms/step - accuracy: 0.9856 - loss: 0.0411 - val_accuracy: 0.7366 - val_loss: 1.7967
# Epoch 349/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 98s 125ms/step - accuracy: 0.9883 - loss: 0.0368 - val_accuracy: 0.7390 - val_loss: 1.7558
# Epoch 350/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 97s 125ms/step - accuracy: 0.9845 - loss: 0.0443 - val_accuracy: 0.7376 - val_loss: 1.7699
# Epoch 351/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 99s 127ms/step - accuracy: 0.9879 - loss: 0.0374 - val_accuracy: 0.7372 - val_loss: 1.7902
# Epoch 352/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 101s 129ms/step - accuracy: 0.9868 - loss: 0.0401 - val_accuracy: 0.7421 - val_loss: 1.7976
# Epoch 353/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 98s 125ms/step - accuracy: 0.9844 - loss: 0.0445 - val_accuracy: 0.7437 - val_loss: 1.7738
# Epoch 354/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 98s 125ms/step - accuracy: 0.9874 - loss: 0.0392 - val_accuracy: 0.7310 - val_loss: 1.8132
# Epoch 355/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 99s 126ms/step - accuracy: 0.9855 - loss: 0.0430 - val_accuracy: 0.7387 - val_loss: 1.7943
# Epoch 356/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 98s 125ms/step - accuracy: 0.9866 - loss: 0.0385 - val_accuracy: 0.7399 - val_loss: 1.7980
# Epoch 357/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 98s 126ms/step - accuracy: 0.9867 - loss: 0.0389 - val_accuracy: 0.7410 - val_loss: 1.7809
# Epoch 358/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 100s 128ms/step - accuracy: 0.9890 - loss: 0.0348 - val_accuracy: 0.7409 - val_loss: 1.7654
# Epoch 359/501
# ...
#  0.1405952  0.13876933 0.1364533  0.13616036 0.13323872 0.12939492
#  0.13455981 0.1306558  0.12967519 0.12434644 0.12638174 0.12477293
#  0.12268642 0.12370019 0.12445907 0.1181566  0.12416499 0.11545035
#  0.11681487 0.11543391 0.11661721 0.11873652 0.11067573 0.1139385
#  0.11122623 0.11270411 0.11183177 0.10789503 0.10599075 0.11047155
#  0.11172652 0.10879633 0.1038515  0.10671143 0.10429905 0.10080142
#  0.10386974 0.09805807 0.1046413  0.09890816 0.09989358 0.10165048
#  0.09913815 0.09450505 0.09324186 0.09544219 0.09606326 0.09540813
#  0.09280904 0.09094936 0.09257073 0.09039699 0.0900461  0.09288309
#  0.09295528 0.08790953 0.09019912 0.08807477 0.0894121  0.08605562
#  0.09106153 0.08149513 0.08913519 0.08827185 0.08478295 0.08016875
#  0.08481667 0.08225174 0.08135272 0.08233419 0.08077697 0.08223947
#  0.07903972 0.08035584 0.08143651 0.07960862 0.07818063 0.07583719
#  0.07817811 0.08087271 0.07415172 0.0774374  0.07702079 0.07492447
#  0.07297383 0.0780297  0.07204539 0.07719833 0.07216627 0.07379288
#  0.0715827  0.07589427 0.07278343 0.07234503 0.0731601  0.07296558
#  0.07276437 0.07382003 0.07195934 0.07055635 0.07493002 0.06714422
#  0.06973535 0.07004648 0.06719742 0.0694148  0.06806904 0.06684827
#  0.06786676 0.06644258 0.06298327 0.0714206  0.0661228  0.06656659
#  0.06457923 0.06593258 0.06773119 0.0659703  0.0670185  0.06440508
#  0.06132341 0.06339926 0.06539357 0.06878016 0.05838529 0.06280529
#  0.06227029 0.06263721 0.06226457 0.06476673 0.06088894 0.05995109
#  0.05878547 0.06280548 0.05977066 0.05955931 0.06042479 0.05969805
#  0.05636652 0.06021475 0.05950566 0.06061605 0.05746497 0.05861003
#  0.06018381 0.05835165 0.06095444 0.05598095 0.05804552 0.05365991
#  0.05831071 0.05925149 0.05836323 0.05418909 0.058248   0.05661755
#  0.06009721 0.05319474 0.05446481 0.05267383 0.05750063 0.05513765
#  0.05462178 0.05445752 0.05485791 0.05142325 0.0570751  0.05411234
#  0.05181419 0.05502724 0.05327269 0.05143223 0.05461629 0.05165584
#  0.0528574  0.05568456 0.05487082 0.05299109 0.0505955  0.05228816
#  0.05221191 0.05059689 0.05079181 0.05513659 0.05138783 0.04997893
#  0.04628858 0.05197821 0.04924567 0.05291157 0.04970938 0.05112086
#  0.04876143 0.04967099 0.04838074 0.05291092 0.04917311 0.04885472
#  0.04969203 0.04853323 0.04673182 0.0479313  0.04963225 0.04694505
#  0.04829093 0.04570616 0.04992037 0.04801779 0.04845501 0.04833437
#  0.04920786 0.04782406 0.04421337 0.04942503 0.0443427  0.04317035
#  0.05076834 0.04575001 0.0445836  0.04702339 0.04675329 0.04579692
#  0.04388455 0.05063176 0.04421611 0.04216406 0.04822123 0.04389302
#  0.04358611 0.04544777 0.04250292 0.04458592 0.04655292 0.04493923
#  0.04570827 0.04168211 0.04480843 0.04566866 0.0458809  0.04479422
#  0.04176868 0.04463169 0.04566516 0.0410983  0.04134536 0.04170446
#  0.04654504 0.04492099 0.04483214 0.04118264 0.04292049 0.04129694
#  0.04084709 0.04411547 0.03886965 0.04175606 0.04291732 0.04109325
#  0.04409272 0.04209416 0.0420125  0.0407823  0.04049779 0.04249093
#  0.04387656 0.04171563 0.03937608 0.04003014 0.04106982 0.04070411
#  0.04323056 0.04136883 0.03806521 0.04241627 0.04481255 0.03844991
#  0.03741731 0.03902858 0.04263258 0.04063968 0.03964221 0.03973518
#  0.03997165 0.03781809 0.04012093 0.04307241 0.0353351  0.04187664
#  0.03793198 0.03945633 0.03717715 0.03654793 0.03907138 0.03776798
#  0.0416751  0.04280503 0.03465577 0.03709834 0.0399863  0.03837244
#  0.03698571 0.04052049 0.03528127 0.04052642 0.03978265 0.03718806
#  0.03979518 0.03812999 0.04134236 0.03558439 0.03551725 0.04019634
#  0.04005541 0.03391437 0.03704564 0.03787207 0.03546885 0.03585828
#  0.03608675 0.03569856 0.0366655  0.03651283 0.03845143 0.03757703
#  0.03302564 0.03571051 0.03803311 0.0377664  0.03873841 0.03581747
#  0.03174856 0.0385485  0.03733609 0.03502493 0.0333589  0.03648042
#  0.03533747 0.03666324 0.037035   0.03683819 0.03451746 0.03627744
#  0.03419938 0.0344973  0.03491497 0.039487   0.03346527 0.03322034
#  0.03571374 0.03376735 0.03291995 0.03908402 0.03440627 0.03460169
#  0.03377594 0.03354409 0.03242946 0.03676439 0.03574497 0.03340139
#  0.0330688  0.03299759 0.03504042 0.03622926 0.03512245 0.03561923
#  0.0345355  0.03437848 0.03465964 0.0334791  0.03242426 0.0344361
#  0.03207257 0.03398758 0.03329647 0.034514   0.03582671 0.03235406
#  0.03505784 0.03227952 0.03556179 0.03322093 0.03449024 0.02844057
#  0.03339631 0.0308826  0.03582363 0.03091894 0.03311905 0.03332198
#  0.03307945 0.03130008 0.0331541  0.02965991 0.03130844 0.03165586
#  0.03592553 0.03297172 0.03158051 0.03332607 0.03363552 0.02875208
#  0.03055133 0.03415412 0.03042185]
#   val_accuracy: [0.53930002 0.60030001 0.6415     0.67930001 0.69220001 0.70200002
#  0.71380001 0.71380001 0.73930001 0.73089999 0.72460002 0.73479998
#  0.73500001 0.73269999 0.73329997 0.73400003 0.74430001 0.74339998
#  0.74049997 0.75059998 0.73900002 0.73659998 0.74629998 0.73580003
#  0.74199998 0.7428     0.7378     0.7511     0.74919999 0.73790002
#  0.74159998 0.74449998 0.75169998 0.74769998 0.73329997 0.745
#  0.75230002 0.7421     0.75010002 0.73280001 0.74650002 0.74190003
#  0.73629999 0.74720001 0.73930001 0.74440002 0.73790002 0.73680001
#  0.74349999 0.73710001 0.74049997 0.74250001 0.74779999 0.73680001
#  0.74830002 0.73369998 0.74379998 0.7489     0.74290001 0.74199998
#  0.73750001 0.74199998 0.74089998 0.73479998 0.74379998 0.74349999
#  0.74080002 0.74349999 0.727      0.7396     0.74169999 0.72369999
#  0.73659998 0.73769999 0.74040002 0.7446     0.73809999 0.73729998
#  0.72890002 0.72240001 0.74119997 0.73760003 0.72899997 0.74080002
#  0.7274     0.7403     0.74409997 0.73559999 0.73119998 0.73519999
#  0.74169999 0.74010003 0.7367     0.73430002 0.74019998 0.73720002
#  0.73519999 0.72899997 0.73809999 0.73979998 0.73689997 0.72680002
#  0.73909998 0.74010003 0.73519999 0.7331     0.7227     0.7378
#  0.73909998 0.7392     0.73710001 0.74159998 0.73089999 0.7335
#  0.73909998 0.73820001 0.71890002 0.73970002 0.74129999 0.73570001
#  0.72850001 0.72850001 0.7367     0.73699999 0.73610002 0.73750001
#  0.74339998 0.7396     0.74260002 0.73439997 0.7367     0.73729998
#  0.73930001 0.7396     0.72530001 0.73869997 0.72960001 0.73549998
#  0.73100001 0.73879999 0.74150002 0.74659997 0.73210001 0.7428
#  0.74299997 0.73369998 0.74129999 0.73540002 0.73760003 0.72960001
#  0.73049998 0.73650002 0.73769999 0.73360002 0.73610002 0.7299
#  0.73869997 0.7378     0.7324     0.73040003 0.74309999 0.7396
#  0.74019998 0.74150002 0.73699999 0.7324     0.73949999 0.73339999
#  0.73979998 0.73610002 0.73659998 0.73629999 0.73479998 0.73400003
#  0.73079997 0.73989999 0.74089998 0.74529999 0.73869997 0.73210001
#  0.74110001 0.73559999 0.7342     0.73830003 0.73159999 0.73710001
#  0.73769999 0.73299998 0.73379999 0.73989999 0.73559999 0.74430001
#  0.74089998 0.73180002 0.73570001 0.73640001 0.73699999 0.73360002
#  0.7414     0.74540001 0.73559999 0.7396     0.73799998 0.73750001
#  0.74220002 0.73820001 0.73460001 0.73329997 0.73259997 0.7324
#  0.74089998 0.73790002 0.73439997 0.73930001 0.73470002 0.7331
#  0.73479998 0.7295     0.73570001 0.73589998 0.73259997 0.73790002
#  0.73449999 0.73699999 0.73559999 0.74379998 0.73729998 0.73830003
#  0.73570001 0.73430002 0.7392     0.73559999 0.73640001 0.73409998
#  0.73659998 0.73259997 0.73940003 0.7432     0.73479998 0.74110001
#  0.73879999 0.74260002 0.74199998 0.73439997 0.73509997 0.73269999
#  0.73640001 0.7432     0.74250001 0.7392     0.73769999 0.7403
#  0.73909998 0.7367     0.73909998 0.7342     0.736      0.74010003
#  0.73570001 0.74080002 0.73949999 0.74190003 0.7378     0.73040003
#  0.73890001 0.73790002 0.73570001 0.736      0.7367     0.7342
#  0.73430002 0.73640001 0.73949999 0.7396     0.73769999 0.73629999
#  0.7414     0.73570001 0.73400003 0.73830003 0.73820001 0.73869997
#  0.7439     0.7335     0.73710001 0.73820001 0.74260002 0.73790002
#  0.74089998 0.74159998 0.73189998 0.73949999 0.74220002 0.736
#  0.73790002 0.72759998 0.73930001 0.73790002 0.7385     0.73979998
#  0.73729998 0.7432     0.74190003 0.73430002 0.7403     0.741
#  0.74309999 0.73650002 0.7353     0.73879999 0.741      0.73540002
#  0.745      0.7385     0.73390001 0.72790003 0.73949999 0.741
#  0.73680001 0.73890001 0.74540001 0.73650002 0.7396     0.73509997
#  0.73559999 0.73619998 0.73650002 0.73299998 0.73269999 0.73689997
#  0.73159999 0.73650002 0.7414     0.74110001 0.73540002 0.73449999
#  0.7392     0.73049998 0.73379999 0.73449999 0.7385     0.73570001
#  0.7392     0.73839998 0.74159998 0.73760003 0.73879999 0.73659998
#  0.73900002 0.73760003 0.73720002 0.7421     0.74370003 0.73100001
#  0.73869997 0.73989999 0.741      0.74089998 0.73860002 0.74000001
#  0.74049997 0.74059999 0.73729998 0.73659998 0.73659998 0.73930001
#  0.73159999 0.73699999 0.73720002 0.73549998 0.7385     0.7396
#  0.73379999 0.72890002 0.7331     0.7374     0.74000001 0.73470002
#  0.73619998 0.73040003 0.73439997 0.7335     0.73610002 0.74059999
#  0.72939998 0.73500001 0.7392     0.74070001 0.7392     0.73629999
#  0.73879999 0.73379999 0.73879999 0.73119998 0.73299998 0.74040002
#  0.74019998 0.73549998 0.74019998 0.73809999 0.73290002 0.7428
#  0.73439997 0.74129999 0.73559999 0.73549998 0.7306     0.7295
#  0.7367     0.7367     0.74239999 0.7428     0.73869997 0.73259997
#  0.73299998 0.74080002 0.73449999 0.74000001 0.7385     0.73500001
#  0.73869997 0.73760003 0.73689997 0.74089998 0.73879999 0.74489999
#  0.73589998 0.74470001 0.74489999 0.73940003 0.73650002 0.73040003
#  0.73799998 0.74379998 0.73839998 0.74019998 0.73720002 0.7353
#  0.7403     0.7367     0.73290002 0.73629999 0.73949999 0.73299998
#  0.7396     0.736      0.74180001 0.74000001 0.73430002 0.74299997
#  0.73890001 0.73580003 0.74000001 0.73640001 0.73989999 0.7392
#  0.7403     0.74119997 0.73799998 0.73979998 0.74049997 0.73949999
#  0.73909998 0.73949999 0.73860002 0.7439     0.73860002 0.73619998
#  0.73680001 0.73809999 0.73689997 0.73640001 0.73909998 0.73619998
#  0.73659998 0.74150002 0.72860003 0.73339999 0.74220002 0.74000001
#  0.73879999 0.74080002 0.73610002 0.74250001 0.73409998 0.73900002
#  0.73339999 0.73610002 0.7439     0.74220002 0.73860002 0.73439997
#  0.73720002 0.74330002 0.73699999 0.73940003 0.74040002 0.73839998
#  0.73949999 0.73809999 0.73900002]
#   val_loss: [1.27087057 1.1365037  1.03685451 0.9283281  0.87732363 0.8437286
#  0.85023957 0.81210262 0.7727524  0.7680825  0.79751462 0.80077183
#  0.80989635 0.79776543 0.83184206 0.80468398 0.78109223 0.78257614
#  0.81188846 0.76025862 0.82168496 0.82150501 0.79715693 0.84997034
#  0.82165635 0.80308032 0.82680964 0.82226163 0.8167876  0.85712862
#  0.8415637  0.85528272 0.84888709 0.8325305  0.89733338 0.87164807
#  0.84943467 0.87267578 0.86982501 0.93616933 0.87950051 0.90000588
#  0.96469277 0.92021006 0.93364561 0.9091084  0.94756854 0.95783037
#  0.91508269 0.94828165 0.94984132 0.95818341 0.94161475 1.00084996
#  0.95269197 1.03988278 0.97001797 0.94332021 0.97588855 0.99939114
#  1.0644592  1.01828206 1.03220475 1.03295004 1.00071418 1.00490248
#  1.01161432 1.05056906 1.13834655 1.07449937 1.03971338 1.12915504
#  1.07693267 1.0770514  1.08828461 1.05652809 1.07064676 1.12688112
#  1.11931479 1.17336142 1.12010956 1.13325667 1.21359181 1.12090933
#  1.17118502 1.10991561 1.08846116 1.12944019 1.19779921 1.14636779
#  1.13321209 1.14840496 1.18481696 1.20709884 1.17513525 1.16833448
#  1.19628823 1.18443501 1.21541262 1.18166053 1.1949352  1.2088933
#  1.18410504 1.18677127 1.21074092 1.22413266 1.25505602 1.21222913
#  1.21978831 1.25063002 1.24252212 1.23229218 1.26603472 1.25698066
#  1.27668989 1.2595861  1.33701372 1.24999702 1.25918198 1.28767526
#  1.30162323 1.30217648 1.26776242 1.28554428 1.28759801 1.27630997
#  1.27604461 1.30995631 1.26945817 1.31811607 1.30439126 1.28431475
#  1.27435923 1.29703355 1.34640217 1.31543529 1.35028505 1.30406964
#  1.35417593 1.31839836 1.33679461 1.31134796 1.35844433 1.33250391
#  1.34267092 1.37373054 1.34057152 1.36650395 1.3699578  1.43480587
#  1.42516136 1.36638856 1.35918403 1.4411155  1.36381125 1.44426763
#  1.36252749 1.36703217 1.40728939 1.39688432 1.35990894 1.40220988
#  1.39722741 1.38900602 1.42434335 1.44717753 1.42757857 1.44255602
#  1.40624321 1.41436899 1.45688915 1.43891263 1.43998528 1.44842768
#  1.49036372 1.44852924 1.43867481 1.4180516  1.45365751 1.46194828
#  1.4596926  1.46821666 1.47902846 1.44995689 1.52107668 1.47651327
#  1.51045346 1.47123539 1.47158194 1.48522389 1.50185347 1.42784846
#  1.50592971 1.49178302 1.48493874 1.47986078 1.47574127 1.5242393
#  1.50722492 1.50487661 1.50493586 1.48442459 1.51254249 1.51218939
#  1.51169097 1.51536345 1.54264486 1.55224097 1.5519774  1.54097974
#  1.51701164 1.52770591 1.51454782 1.53978384 1.58019102 1.63572204
#  1.57375169 1.55575407 1.54411626 1.58508253 1.65008783 1.59571302
#  1.57272911 1.54532719 1.55234039 1.52791297 1.58075631 1.60606098
#  1.59630525 1.6162107  1.57426882 1.59322834 1.58340156 1.60168374
#  1.60339701 1.62821221 1.56982946 1.5776937  1.58702183 1.58154702
#  1.60887182 1.58201766 1.56828928 1.60791254 1.62363875 1.6568768
#  1.63060439 1.61672914 1.58814108 1.62837982 1.63187778 1.61147285
#  1.60165858 1.6146735  1.61001635 1.61949909 1.63610888 1.61408424
#  1.63004553 1.61343074 1.64623022 1.65109301 1.66172206 1.70349336
#  1.69973111 1.66005158 1.65751481 1.68522441 1.6800791  1.67854846
#  1.72943008 1.69624937 1.67303872 1.67454958 1.67399943 1.66630995
#  1.65940702 1.68665195 1.66152012 1.68746388 1.64530933 1.64628589
#  1.68161464 1.69947124 1.67386293 1.6738348  1.65829217 1.68576753
#  1.71682656 1.7057066  1.73990679 1.69663632 1.67206872 1.71267557
#  1.69398558 1.76067579 1.72573948 1.71292865 1.69441545 1.69370842
#  1.71335316 1.69056249 1.72993422 1.72320199 1.70855761 1.74861717
#  1.73227382 1.75383186 1.71569633 1.72573709 1.73793066 1.76662576
#  1.70027125 1.70286214 1.76805961 1.80277348 1.74920666 1.71890152
#  1.75989342 1.74381137 1.71775997 1.76486254 1.69987166 1.74829626
#  1.74004984 1.78345037 1.75043666 1.77350545 1.81716681 1.77403903
#  1.78361607 1.77963316 1.78071678 1.81337202 1.80434394 1.76054513
#  1.78805256 1.77054119 1.76362574 1.76926899 1.8056252  1.80479395
#  1.80118549 1.80607462 1.77592361 1.78639257 1.78950369 1.79673028
#  1.755759   1.76986802 1.79023576 1.79757929 1.77380335 1.81317163
#  1.79428554 1.79800272 1.78085327 1.76539588 1.79006779 1.79102695
#  1.78222191 1.83148575 1.84144747 1.85821724 1.81875408 1.79851186
#  1.88272202 1.78272212 1.79696822 1.86163437 1.78149867 1.78205943
#  1.82625413 1.89767182 1.82213259 1.81765366 1.82258892 1.82047915
#  1.81877732 1.83975863 1.86400819 1.88557732 1.83235824 1.85485995
#  1.87686646 1.88223791 1.80606115 1.83067715 1.80518472 1.90370786
#  1.83808362 1.86621439 1.86276448 1.88122809 1.89511108 1.84286177
#  1.82129276 1.91146779 1.85342634 1.83661544 1.91618598 1.84907699
#  1.83940995 1.82956958 1.88348281 1.86030877 1.93071508 1.92533541
#  1.86253452 1.84518301 1.84070349 1.85636795 1.86657536 1.93043578
#  1.89695883 1.85145533 1.90747678 1.90483463 1.87684906 1.92117894
#  1.87029898 1.89186835 1.8982662  1.88409126 1.8715297  1.87356508
#  1.91311991 1.82973361 1.85548031 1.87419534 1.93634439 1.94231582
#  1.89871252 1.87686372 1.88721681 1.93690407 1.8984648  1.89761734
#  1.91458809 1.92955744 1.89943492 1.94026017 1.91534531 1.98362553
#  1.89734495 1.95776677 1.92606294 1.88841701 1.98072577 1.91338217
#  1.91548634 1.95281208 1.91081989 1.92068362 1.90790331 1.92860389
#  1.92460334 1.94086933 1.94604182 1.89493299 1.90862751 1.93609977
#  1.92443728 1.90670741 1.91730249 1.92558765 1.91816604 1.92866349
#  1.90750468 1.93241334 1.96117795 1.97458458 1.9228363  1.92982662
#  1.9042176  1.91725171 1.95642543 1.97878456 1.96883845 1.98284197
#  1.90770233 1.9669373  1.97510743 1.9239428  2.00323272 2.05522704
#  1.96106327 1.98641157 1.91252327 1.96488929 1.92630756 1.97743809
#  1.9433105  1.94487047 1.94941819 1.97040701 1.95559788 1.98734272
#  1.9608469  1.9628408  1.93538785]
#  -------------------
# --- Loading accuracy_000.npz and loss_000.npz ---
# Keys accuracy: ['ReLU6', 'GELU', 'LSGELU', 'XSINELU', 'XSINELU2Pi', 'ELU', 'Swish', 'ReLU', 'SECHLU']
# Keys loss: ['ReLU6', 'GELU', 'LSGELU', 'XSINELU', 'XSINELU2Pi', 'ELU', 'Swish', 'ReLU', 'SECHLU']
# END at 2025-08-15 12:07:06
