# %%
#--- 2025-07-20 01-05 – by Dr. Thawatchai Chomsiri  
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, DepthwiseConv2D, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Activation
from tensorflow.keras.models import Model
import datetime

import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Flatten, Dense
import matplotlib.pyplot as plt
import datetime
import numpy as np
import os
import re
import math
import pickle


# Define relu6
def relu6(x):
    return tf.keras.activations.relu(x, max_value=6)

# Define paralu
def paralu(x):
    cube_root_of_three = 3 ** (1/3)
    return tf.where(
        x >= 0,
        x,
        tf.where(
            x >= -cube_root_of_three,
            x * (1/3) * tf.pow(x + cube_root_of_three, 3),
            tf.zeros_like(x)
        )
    )

def lsgelu(x):    # Left-Shifted GELU with 1 range
    return x * 0.5 * (1 + tf.math.erf((x + 1.5) / tf.sqrt(2.0)))

"""  old version, will be wrong for x-> (x+Pi)
def xsinelu(x):
    Pi = math.pi
    return tf.where(
        x >= Pi,
        x,
        tf.where(
            x >= -1 * Pi,
            (1/2) * (( ((x * tf.sin(x)) + (x * x) ) / Pi ) + x),
            tf.zeros_like(x)
        )
    )  
"""
def xsinelu(x):
    Pi = math.pi
    return tf.where(
        x >= Pi,
        x,
        tf.where(
            x >= -1 * Pi,
            x * ( ((tf.sin(x)) + x + Pi ) / (2*Pi) ),
            tf.zeros_like(x)
        )
    )  

def xsinelu2pi(x):
    Pi = math.pi
    return tf.where(
        x >= 0,
        x,
        tf.where(
            x >= -2 * Pi,
            x * ( ((tf.sin(x+Pi)) + (x+Pi) + Pi ) / (2*Pi) ),
            tf.zeros_like(x)
        )
    )  

# Function สำหรับสร้างโมเดล
def build_model(activation_fn):
    inputs = Input(shape=(32, 32, 3))
    x = Conv2D(32, (3, 3), strides=2, padding='same', activation=None)(inputs)
    x = BatchNormalization()(x)
    x = Activation(activation_fn)(x)

    def bottleneck_block(x, filters):
        dw = DepthwiseConv2D((3, 3), padding='same')(x)
        dw = BatchNormalization()(dw)
        dw = Activation(activation_fn)(dw)

        pw = Conv2D(filters, (1, 1), padding='same')(dw)
        pw = BatchNormalization()(pw)
        pw = Activation(activation_fn)(pw)
        return pw

    x = bottleneck_block(x, 64)
    x = bottleneck_block(x, 64)
    x = MaxPooling2D((2, 2))(x)
    x = bottleneck_block(x, 128)
    x = bottleneck_block(x, 128)

    x = GlobalAveragePooling2D()(x)
    outputs = Dense(10, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

activations_list = {
    #'LSGELU': lsgelu,
    #'GELU': tf.nn.gelu,
    #'PARALU': paralu,
    #'ReLU6': 'relu6',
    #'XSINELU': xsinelu,
    #'XSINELU2Pi': xsinelu2pi,
    'ELU': tf.nn.elu,
    'ReLU': tf.nn.relu,
    'Swish': tf.nn.swish,
    
}

epochs = 501  ################
num_runs = 1 ###############
batch_size = 64 ###############
results = {
    'activation': [],
    'accuracy_per_epoch': []
}
accuracy_summary = {}

for run_idx in range(num_runs):
    print(f"\n--- Run {run_idx:03d} of {num_runs:03d} ---")
    results = {}
    accuracy_results = {}
    loss_results = {}
    
    for act_name, act_fn in activations_list.items():
        print(f"Running: Activation={act_name} at {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

        # เทรน
        model = build_model(act_fn)
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                            loss='sparse_categorical_crossentropy',
                            metrics=['accuracy'])

        history = model.fit(x_train, y_train, epochs=epochs, validation_data=(x_test, y_test), batch_size=batch_size)
        
        print(f"Running: Activation={act_name} at {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")   
        results[act_name] = {key: np.array(val) for key, val in history.history.items()}
        print(f"Details in results for round {run_idx:03d}:")
        for act_name, metrics_dict in results.items():
            print(f"\nActivation: {act_name}")
            for metric_name, metric_values in metrics_dict.items():
                print(f"  {metric_name}: {metric_values}")

        # Plot Accuracy
        plt.figure(figsize=(15,8))
        for key, hist_vals in results.items():
            plt.plot(hist_vals['accuracy'], label=key)
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.title('Accuracy')
        plt.legend()
        plt.grid()
        plt.show()
        # Plot Loss
        plt.figure(figsize=(15,8))
        for key, hist_vals in results.items():
            plt.plot(hist_vals['loss'], label=key)
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title('Loss')
        plt.legend()
        plt.grid()
        plt.show()

        np.savez(f"accuracy_{run_idx:03d}_{act_name}.npz", accuracy=np.array(history.history['accuracy']))
        np.savez(f"loss_{run_idx:03d}_{act_name}.npz", loss=np.array(history.history['loss']))
        
        accuracy_results[act_name] = np.array(history.history['accuracy'])
        loss_results[act_name] = np.array(history.history['loss'])

    print(f" ----- Data -------- ")
    results[act_name] = {key: np.array(val) for key, val in history.history.items()}
    print(f"Details in results for round {run_idx:03d}:")
    for act_name, metrics_dict in results.items():
        print(f"\nActivation: {act_name}")
        for metric_name, metric_values in metrics_dict.items():
            print(f"  {metric_name}: {metric_values}")

    print(f" ------------------- ")
    ###np.savez(f"accuracy_{run_idx:03d}.npz", **accuracy_results)
    ###np.savez(f"loss_{run_idx:03d}.npz", **loss_results)

folder_path = '.'
accuracy_files = sorted([f for f in os.listdir(folder_path) if re.match(r'accuracy_\d+\.npz', f)])
loss_files = sorted([f for f in os.listdir(folder_path) if re.match(r'loss_\d+\.npz', f)])

accuracy_collections = {}
for fname in accuracy_files:
    acc_data = np.load(os.path.join(folder_path, fname), allow_pickle=True)
    for key in acc_data.files:
        if key not in accuracy_collections:
            accuracy_collections[key] = []
        accuracy_collections[key].append(acc_data[key])

accuracy_avg = {}
for act_name, vals in accuracy_collections.items():
    stacked = np.vstack(vals)
    accuracy_avg[act_name] = np.mean(stacked, axis=0)

loss_collections = {}
for fname in loss_files:
    los_data = np.load(os.path.join(folder_path, fname), allow_pickle=True)
    for key in los_data.files:
        if key not in loss_collections:
            loss_collections[key] = []
        loss_collections[key].append(los_data[key])

loss_avg = {}
for act_name, vals in loss_collections.items():
    stacked = np.vstack(vals)
    loss_avg[act_name] = np.mean(stacked, axis=0)

plt.figure(figsize=(15,8))
for i, act_name in enumerate(accuracy_avg):
    plt.plot(accuracy_avg[act_name], label=act_name)
plt.xlabel('Epoch')
plt.ylabel('Average Accuracy')
plt.title('Average Accuracy of Activation Functions')
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(15,8))
for i, act_name in enumerate(loss_avg):
    plt.plot(loss_avg[act_name], label=act_name)
plt.xlabel('Epoch')
plt.ylabel('Average Loss')
plt.title('Average Loss of Activation Functions')
plt.legend()
plt.grid()
plt.show()

for i in range(len(accuracy_files)):
    fname_acc = accuracy_files[i]
    fname_loss = loss_files[i]
    print(f"\n--- Loading {fname_acc} and {fname_loss} ---")
    acc_data = np.load(os.path.join(folder_path, fname_acc), allow_pickle=True)
    loss_data = np.load(os.path.join(folder_path, fname_loss), allow_pickle=True)

    print("Keys accuracy:", list(acc_data.keys()))
    print("Keys loss:", list(loss_data.keys()))

    activation_names = list(acc_data.files)

    # Plot Accuracy
    plt.figure(figsize=(15,8))
    for name in activation_names:
        plt.plot(acc_data[name], label=name)
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title(f'Accuracy from {fname_acc}')
    plt.legend()
    plt.grid()
    plt.show()
    # Plot Loss
    plt.figure(figsize=(15,8))
    for name in activation_names:
        plt.plot(loss_data[name], label=name)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'Loss from {fname_loss}')
    plt.legend()
    plt.grid()
    plt.show()
   
print(f"\nEND at {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 101s 1us/step
#
# --- Run 000 of 001 ---
# Running: Activation=ELU at 2025-07-20 01:07:51
# Epoch 1/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 49s 57ms/step - accuracy: 0.4391 - loss: 1.5457 - val_accuracy: 0.5216 - val_loss: 1.3230
# Epoch 2/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 54ms/step - accuracy: 0.6035 - loss: 1.1053 - val_accuracy: 0.5789 - val_loss: 1.1935
# Epoch 3/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 45s 58ms/step - accuracy: 0.6608 - loss: 0.9643 - val_accuracy: 0.6443 - val_loss: 1.0101
# Epoch 4/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 54ms/step - accuracy: 0.6881 - loss: 0.8876 - val_accuracy: 0.6614 - val_loss: 0.9620
# Epoch 5/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 45s 58ms/step - accuracy: 0.7082 - loss: 0.8285 - val_accuracy: 0.6677 - val_loss: 0.9560
# Epoch 6/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 44s 56ms/step - accuracy: 0.7246 - loss: 0.7846 - val_accuracy: 0.6869 - val_loss: 0.8837
# Epoch 7/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 47s 60ms/step - accuracy: 0.7387 - loss: 0.7409 - val_accuracy: 0.6829 - val_loss: 0.9252
# Epoch 8/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 44s 57ms/step - accuracy: 0.7530 - loss: 0.7095 - val_accuracy: 0.6969 - val_loss: 0.8741
# Epoch 9/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 45s 58ms/step - accuracy: 0.7629 - loss: 0.6793 - val_accuracy: 0.7096 - val_loss: 0.8350
# Epoch 10/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.7749 - loss: 0.6455 - val_accuracy: 0.7152 - val_loss: 0.8290
# Epoch 11/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 45s 58ms/step - accuracy: 0.7775 - loss: 0.6332 - val_accuracy: 0.6757 - val_loss: 0.9605
# Epoch 12/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 54ms/step - accuracy: 0.7837 - loss: 0.6164 - val_accuracy: 0.7283 - val_loss: 0.7883
# Epoch 13/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.7945 - loss: 0.5877 - val_accuracy: 0.7235 - val_loss: 0.8056
# Epoch 14/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 54ms/step - accuracy: 0.8029 - loss: 0.5658 - val_accuracy: 0.7079 - val_loss: 0.8737
# Epoch 15/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.8038 - loss: 0.5609 - val_accuracy: 0.7486 - val_loss: 0.7607
# Epoch 16/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.8071 - loss: 0.5388 - val_accuracy: 0.7386 - val_loss: 0.7821
# Epoch 17/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 44s 56ms/step - accuracy: 0.8173 - loss: 0.5214 - val_accuracy: 0.7205 - val_loss: 0.8311
# Epoch 18/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 54ms/step - accuracy: 0.8222 - loss: 0.5096 - val_accuracy: 0.7390 - val_loss: 0.7662
# Epoch 19/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 44s 56ms/step - accuracy: 0.8265 - loss: 0.4972 - val_accuracy: 0.7260 - val_loss: 0.8211
# Epoch 20/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 54ms/step - accuracy: 0.8327 - loss: 0.4828 - val_accuracy: 0.7264 - val_loss: 0.8262
# Epoch 21/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.8349 - loss: 0.4717 - val_accuracy: 0.7319 - val_loss: 0.8027
# Epoch 22/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 54ms/step - accuracy: 0.8367 - loss: 0.4690 - val_accuracy: 0.7400 - val_loss: 0.7800
# Epoch 23/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 45s 57ms/step - accuracy: 0.8363 - loss: 0.4610 - val_accuracy: 0.7314 - val_loss: 0.8241
# Epoch 24/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 45s 58ms/step - accuracy: 0.8407 - loss: 0.4521 - val_accuracy: 0.7398 - val_loss: 0.8013
# Epoch 25/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 46s 59ms/step - accuracy: 0.8463 - loss: 0.4378 - val_accuracy: 0.7323 - val_loss: 0.8150
# Epoch 26/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 45s 58ms/step - accuracy: 0.8492 - loss: 0.4350 - val_accuracy: 0.7456 - val_loss: 0.7797
# Epoch 27/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 46s 59ms/step - accuracy: 0.8559 - loss: 0.4110 - val_accuracy: 0.7424 - val_loss: 0.7862
# Epoch 28/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 46s 58ms/step - accuracy: 0.8540 - loss: 0.4169 - val_accuracy: 0.7383 - val_loss: 0.8253
# Epoch 29/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 47s 60ms/step - accuracy: 0.8605 - loss: 0.4009 - val_accuracy: 0.7454 - val_loss: 0.7773
# Epoch 30/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 46s 59ms/step - accuracy: 0.8610 - loss: 0.3920 - val_accuracy: 0.7465 - val_loss: 0.7900
# Epoch 31/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 47s 60ms/step - accuracy: 0.8625 - loss: 0.3909 - val_accuracy: 0.7415 - val_loss: 0.8123
# Epoch 32/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 46s 59ms/step - accuracy: 0.8670 - loss: 0.3781 - val_accuracy: 0.7441 - val_loss: 0.8001
# Epoch 33/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 47s 60ms/step - accuracy: 0.8685 - loss: 0.3758 - val_accuracy: 0.7359 - val_loss: 0.8421
# Epoch 34/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 47s 59ms/step - accuracy: 0.8662 - loss: 0.3743 - val_accuracy: 0.7337 - val_loss: 0.8528
# Epoch 35/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 47s 61ms/step - accuracy: 0.8718 - loss: 0.3613 - val_accuracy: 0.7188 - val_loss: 0.9322
# Epoch 36/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 47s 60ms/step - accuracy: 0.8762 - loss: 0.3527 - val_accuracy: 0.7346 - val_loss: 0.8582
# Epoch 37/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 48s 61ms/step - accuracy: 0.8779 - loss: 0.3516 - val_accuracy: 0.7462 - val_loss: 0.8151
# Epoch 38/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 46s 59ms/step - accuracy: 0.8777 - loss: 0.3483 - val_accuracy: 0.7388 - val_loss: 0.8698
# Epoch 39/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 48s 61ms/step - accuracy: 0.8844 - loss: 0.3336 - val_accuracy: 0.7455 - val_loss: 0.8324
# Epoch 40/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 47s 60ms/step - accuracy: 0.8856 - loss: 0.3252 - val_accuracy: 0.7272 - val_loss: 0.9092
# Epoch 41/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 48s 61ms/step - accuracy: 0.8834 - loss: 0.3239 - val_accuracy: 0.7313 - val_loss: 0.9147
# Epoch 42/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 47s 60ms/step - accuracy: 0.8878 - loss: 0.3216 - val_accuracy: 0.7337 - val_loss: 0.9060
# Epoch 43/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 48s 62ms/step - accuracy: 0.8874 - loss: 0.3195 - val_accuracy: 0.7496 - val_loss: 0.8524
# Epoch 44/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 47s 61ms/step - accuracy: 0.8909 - loss: 0.3157 - val_accuracy: 0.7344 - val_loss: 0.8970
# Epoch 45/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 48s 62ms/step - accuracy: 0.8937 - loss: 0.3025 - val_accuracy: 0.7385 - val_loss: 0.8715
# Epoch 46/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 47s 61ms/step - accuracy: 0.8941 - loss: 0.3003 - val_accuracy: 0.7463 - val_loss: 0.8416
# Epoch 47/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 49s 62ms/step - accuracy: 0.8966 - loss: 0.2970 - val_accuracy: 0.7479 - val_loss: 0.8556
# Epoch 48/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 48s 61ms/step - accuracy: 0.8985 - loss: 0.2883 - val_accuracy: 0.7343 - val_loss: 0.9003
# Epoch 49/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 49s 62ms/step - accuracy: 0.8992 - loss: 0.2903 - val_accuracy: 0.7332 - val_loss: 0.9297
# Epoch 50/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 48s 61ms/step - accuracy: 0.9008 - loss: 0.2866 - val_accuracy: 0.7483 - val_loss: 0.8601
# Epoch 51/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 49s 63ms/step - accuracy: 0.9012 - loss: 0.2833 - val_accuracy: 0.7400 - val_loss: 0.8929
# Epoch 52/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 48s 62ms/step - accuracy: 0.9006 - loss: 0.2803 - val_accuracy: 0.7402 - val_loss: 0.9036
# Epoch 53/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 49s 63ms/step - accuracy: 0.9018 - loss: 0.2751 - val_accuracy: 0.7476 - val_loss: 0.9071
# Epoch 54/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 49s 62ms/step - accuracy: 0.9056 - loss: 0.2700 - val_accuracy: 0.7375 - val_loss: 0.9253
# Epoch 55/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 64ms/step - accuracy: 0.9105 - loss: 0.2592 - val_accuracy: 0.7475 - val_loss: 0.8876
# Epoch 56/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - accuracy: 0.9051 - loss: 0.2653 - val_accuracy: 0.7375 - val_loss: 0.9757
# Epoch 57/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 64ms/step - accuracy: 0.9065 - loss: 0.2598 - val_accuracy: 0.7386 - val_loss: 0.9128
# Epoch 58/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 49s 62ms/step - accuracy: 0.9104 - loss: 0.2513 - val_accuracy: 0.7433 - val_loss: 0.9197
# Epoch 59/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 64ms/step - accuracy: 0.9105 - loss: 0.2517 - val_accuracy: 0.7510 - val_loss: 0.9122
# Epoch 60/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 49s 63ms/step - accuracy: 0.9127 - loss: 0.2507 - val_accuracy: 0.7450 - val_loss: 0.9249
# Epoch 61/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 64ms/step - accuracy: 0.9136 - loss: 0.2458 - val_accuracy: 0.7377 - val_loss: 0.9603
# Epoch 62/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 49s 63ms/step - accuracy: 0.9164 - loss: 0.2368 - val_accuracy: 0.7435 - val_loss: 0.9266
# Epoch 63/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 64ms/step - accuracy: 0.9164 - loss: 0.2365 - val_accuracy: 0.7339 - val_loss: 0.9848
# Epoch 64/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 49s 63ms/step - accuracy: 0.9188 - loss: 0.2346 - val_accuracy: 0.7422 - val_loss: 0.9611
# Epoch 65/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 64ms/step - accuracy: 0.9171 - loss: 0.2351 - val_accuracy: 0.7422 - val_loss: 0.9533
# Epoch 66/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 49s 63ms/step - accuracy: 0.9211 - loss: 0.2252 - val_accuracy: 0.7145 - val_loss: 1.0917
# Epoch 67/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.9211 - loss: 0.2232 - val_accuracy: 0.7378 - val_loss: 0.9571
# Epoch 68/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 64ms/step - accuracy: 0.9224 - loss: 0.2218 - val_accuracy: 0.7344 - val_loss: 0.9882
# Epoch 69/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.9200 - loss: 0.2266 - val_accuracy: 0.7415 - val_loss: 0.9698
# Epoch 70/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 64ms/step - accuracy: 0.9222 - loss: 0.2156 - val_accuracy: 0.7397 - val_loss: 0.9924
# Epoch 71/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.9250 - loss: 0.2126 - val_accuracy: 0.7454 - val_loss: 0.9429
# Epoch 72/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 64ms/step - accuracy: 0.9287 - loss: 0.2081 - val_accuracy: 0.7450 - val_loss: 0.9754
# Epoch 73/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.9286 - loss: 0.2030 - val_accuracy: 0.7386 - val_loss: 0.9849
# Epoch 74/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.9296 - loss: 0.2011 - val_accuracy: 0.7427 - val_loss: 0.9999
# Epoch 75/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 66ms/step - accuracy: 0.9281 - loss: 0.2016 - val_accuracy: 0.7397 - val_loss: 0.9927
# Epoch 76/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 64ms/step - accuracy: 0.9346 - loss: 0.1949 - val_accuracy: 0.7420 - val_loss: 1.0121
# Epoch 77/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - accuracy: 0.9325 - loss: 0.1933 - val_accuracy: 0.7475 - val_loss: 0.9892
# Epoch 78/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 64ms/step - accuracy: 0.9329 - loss: 0.1908 - val_accuracy: 0.7398 - val_loss: 1.0423
# Epoch 79/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - accuracy: 0.9325 - loss: 0.1943 - val_accuracy: 0.7482 - val_loss: 1.0096
# Epoch 80/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.9365 - loss: 0.1845 - val_accuracy: 0.7470 - val_loss: 0.9985
# Epoch 81/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - accuracy: 0.9356 - loss: 0.1847 - val_accuracy: 0.7492 - val_loss: 1.0074
# Epoch 82/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.9340 - loss: 0.1890 - val_accuracy: 0.7372 - val_loss: 1.0632
# Epoch 83/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 67ms/step - accuracy: 0.9380 - loss: 0.1772 - val_accuracy: 0.7392 - val_loss: 1.0451
# Epoch 84/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.9352 - loss: 0.1828 - val_accuracy: 0.7401 - val_loss: 1.0609
# Epoch 85/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 53s 68ms/step - accuracy: 0.9361 - loss: 0.1805 - val_accuracy: 0.7464 - val_loss: 1.0435
# Epoch 86/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - accuracy: 0.9398 - loss: 0.1726 - val_accuracy: 0.7335 - val_loss: 1.0616
# Epoch 87/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 53s 67ms/step - accuracy: 0.9357 - loss: 0.1836 - val_accuracy: 0.7471 - val_loss: 1.0366
# Epoch 88/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 67ms/step - accuracy: 0.9388 - loss: 0.1747 - val_accuracy: 0.7416 - val_loss: 1.0682
# Epoch 89/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 67ms/step - accuracy: 0.9365 - loss: 0.1759 - val_accuracy: 0.7398 - val_loss: 1.0748
# Epoch 90/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 53s 68ms/step - accuracy: 0.9426 - loss: 0.1645 - val_accuracy: 0.7430 - val_loss: 1.0675
# Epoch 91/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 53s 67ms/step - accuracy: 0.9429 - loss: 0.1615 - val_accuracy: 0.7477 - val_loss: 1.0841
# Epoch 92/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 67ms/step - accuracy: 0.9424 - loss: 0.1660 - val_accuracy: 0.7332 - val_loss: 1.1475
# Epoch 93/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 53s 67ms/step - accuracy: 0.9404 - loss: 0.1673 - val_accuracy: 0.7378 - val_loss: 1.1017
# Epoch 94/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - accuracy: 0.9432 - loss: 0.1591 - val_accuracy: 0.7370 - val_loss: 1.1075
# Epoch 95/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 53s 68ms/step - accuracy: 0.9452 - loss: 0.1608 - val_accuracy: 0.7327 - val_loss: 1.1541
# Epoch 96/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 67ms/step - accuracy: 0.9425 - loss: 0.1610 - val_accuracy: 0.7436 - val_loss: 1.1013
# Epoch 97/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.9459 - loss: 0.1579 - val_accuracy: 0.7355 - val_loss: 1.1476
# Epoch 98/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - accuracy: 0.9468 - loss: 0.1556 - val_accuracy: 0.7403 - val_loss: 1.1272
# Epoch 99/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 67ms/step - accuracy: 0.9455 - loss: 0.1545 - val_accuracy: 0.7396 - val_loss: 1.1477
# Epoch 100/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.9496 - loss: 0.1472 - val_accuracy: 0.7383 - val_loss: 1.1276
# Epoch 101/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 53s 68ms/step - accuracy: 0.9471 - loss: 0.1507 - val_accuracy: 0.7444 - val_loss: 1.0975
# Epoch 102/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 53s 67ms/step - accuracy: 0.9492 - loss: 0.1447 - val_accuracy: 0.7349 - val_loss: 1.1715
# Epoch 103/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 71ms/step - accuracy: 0.9470 - loss: 0.1495 - val_accuracy: 0.7451 - val_loss: 1.1162
# Epoch 104/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.9537 - loss: 0.1384 - val_accuracy: 0.7391 - val_loss: 1.1256
# Epoch 105/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 70ms/step - accuracy: 0.9517 - loss: 0.1422 - val_accuracy: 0.7365 - val_loss: 1.1690
# Epoch 106/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 70ms/step - accuracy: 0.9501 - loss: 0.1396 - val_accuracy: 0.7369 - val_loss: 1.1663
# Epoch 107/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.9504 - loss: 0.1394 - val_accuracy: 0.7387 - val_loss: 1.1773
# Epoch 108/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 68ms/step - accuracy: 0.9495 - loss: 0.1456 - val_accuracy: 0.7394 - val_loss: 1.1678
# Epoch 109/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 70ms/step - accuracy: 0.9509 - loss: 0.1383 - val_accuracy: 0.7430 - val_loss: 1.1363
# Epoch 110/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 53s 68ms/step - accuracy: 0.9536 - loss: 0.1323 - val_accuracy: 0.7312 - val_loss: 1.1895
# Epoch 111/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 70ms/step - accuracy: 0.9521 - loss: 0.1355 - val_accuracy: 0.7430 - val_loss: 1.1274
# Epoch 112/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.9554 - loss: 0.1312 - val_accuracy: 0.7448 - val_loss: 1.1418
# Epoch 113/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 70ms/step - accuracy: 0.9520 - loss: 0.1369 - val_accuracy: 0.7409 - val_loss: 1.1664
# Epoch 114/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.9562 - loss: 0.1307 - val_accuracy: 0.7367 - val_loss: 1.2039
# Epoch 115/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 70ms/step - accuracy: 0.9566 - loss: 0.1279 - val_accuracy: 0.7415 - val_loss: 1.2144
# Epoch 116/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.9549 - loss: 0.1312 - val_accuracy: 0.7418 - val_loss: 1.1962
# Epoch 117/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 71ms/step - accuracy: 0.9558 - loss: 0.1285 - val_accuracy: 0.7393 - val_loss: 1.1975
# Epoch 118/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.9562 - loss: 0.1253 - val_accuracy: 0.7394 - val_loss: 1.1841
# Epoch 119/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 70ms/step - accuracy: 0.9591 - loss: 0.1226 - val_accuracy: 0.7390 - val_loss: 1.2387
# Epoch 120/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 70ms/step - accuracy: 0.9579 - loss: 0.1222 - val_accuracy: 0.7397 - val_loss: 1.2086
# Epoch 121/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 71ms/step - accuracy: 0.9567 - loss: 0.1236 - val_accuracy: 0.7455 - val_loss: 1.1838
# Epoch 122/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 70ms/step - accuracy: 0.9561 - loss: 0.1281 - val_accuracy: 0.7380 - val_loss: 1.2384
# Epoch 123/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 57s 72ms/step - accuracy: 0.9567 - loss: 0.1220 - val_accuracy: 0.7352 - val_loss: 1.2335
# Epoch 124/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 71ms/step - accuracy: 0.9583 - loss: 0.1196 - val_accuracy: 0.7407 - val_loss: 1.2163
# Epoch 125/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 57s 73ms/step - accuracy: 0.9602 - loss: 0.1164 - val_accuracy: 0.7360 - val_loss: 1.2340
# Epoch 126/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 70ms/step - accuracy: 0.9604 - loss: 0.1136 - val_accuracy: 0.7425 - val_loss: 1.2183
# Epoch 127/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 72ms/step - accuracy: 0.9562 - loss: 0.1213 - val_accuracy: 0.7274 - val_loss: 1.2852
# Epoch 128/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 70ms/step - accuracy: 0.9585 - loss: 0.1171 - val_accuracy: 0.7365 - val_loss: 1.2537
# Epoch 129/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 72ms/step - accuracy: 0.9620 - loss: 0.1098 - val_accuracy: 0.7354 - val_loss: 1.2533
# Epoch 130/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 71ms/step - accuracy: 0.9590 - loss: 0.1171 - val_accuracy: 0.7425 - val_loss: 1.2267
# Epoch 131/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 72ms/step - accuracy: 0.9630 - loss: 0.1110 - val_accuracy: 0.7385 - val_loss: 1.2462
# Epoch 132/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 71ms/step - accuracy: 0.9619 - loss: 0.1118 - val_accuracy: 0.7424 - val_loss: 1.2330
# Epoch 133/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 72ms/step - accuracy: 0.9598 - loss: 0.1144 - val_accuracy: 0.7352 - val_loss: 1.3008
# Epoch 134/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 71ms/step - accuracy: 0.9605 - loss: 0.1121 - val_accuracy: 0.7398 - val_loss: 1.2459
# Epoch 135/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 57s 72ms/step - accuracy: 0.9630 - loss: 0.1082 - val_accuracy: 0.7391 - val_loss: 1.2557
# Epoch 136/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 71ms/step - accuracy: 0.9638 - loss: 0.1059 - val_accuracy: 0.7405 - val_loss: 1.2417
# Epoch 137/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 57s 72ms/step - accuracy: 0.9622 - loss: 0.1079 - val_accuracy: 0.7411 - val_loss: 1.2770
# Epoch 138/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 71ms/step - accuracy: 0.9636 - loss: 0.1064 - val_accuracy: 0.7400 - val_loss: 1.2712
# Epoch 139/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 57s 73ms/step - accuracy: 0.9626 - loss: 0.1078 - val_accuracy: 0.7334 - val_loss: 1.2901
# Epoch 140/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 72ms/step - accuracy: 0.9659 - loss: 0.1005 - val_accuracy: 0.7421 - val_loss: 1.2866
# Epoch 141/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.9646 - loss: 0.1068 - val_accuracy: 0.7388 - val_loss: 1.2871
# Epoch 142/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 72ms/step - accuracy: 0.9667 - loss: 0.0989 - val_accuracy: 0.7335 - val_loss: 1.3369
# Epoch 143/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 57s 73ms/step - accuracy: 0.9662 - loss: 0.1002 - val_accuracy: 0.7423 - val_loss: 1.2728
# Epoch 144/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 72ms/step - accuracy: 0.9635 - loss: 0.1032 - val_accuracy: 0.7461 - val_loss: 1.2879
# Epoch 145/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.9659 - loss: 0.0992 - val_accuracy: 0.7402 - val_loss: 1.2849
# Epoch 146/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 57s 72ms/step - accuracy: 0.9655 - loss: 0.1037 - val_accuracy: 0.7392 - val_loss: 1.3126
# Epoch 147/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.9673 - loss: 0.0956 - val_accuracy: 0.7409 - val_loss: 1.2903
# Epoch 148/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 57s 72ms/step - accuracy: 0.9655 - loss: 0.1004 - val_accuracy: 0.7469 - val_loss: 1.3031
# Epoch 149/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.9669 - loss: 0.0964 - val_accuracy: 0.7413 - val_loss: 1.3109
# Epoch 150/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 57s 73ms/step - accuracy: 0.9668 - loss: 0.0962 - val_accuracy: 0.7382 - val_loss: 1.3431
# Epoch 151/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.9647 - loss: 0.0989 - val_accuracy: 0.7304 - val_loss: 1.3817
# Epoch 152/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 76ms/step - accuracy: 0.9665 - loss: 0.0955 - val_accuracy: 0.7436 - val_loss: 1.2935
# Epoch 153/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 75ms/step - accuracy: 0.9667 - loss: 0.0951 - val_accuracy: 0.7398 - val_loss: 1.3121
# Epoch 154/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.9694 - loss: 0.0924 - val_accuracy: 0.7418 - val_loss: 1.3103
# Epoch 155/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.9676 - loss: 0.0930 - val_accuracy: 0.7417 - val_loss: 1.3369
# Epoch 156/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.9655 - loss: 0.0980 - val_accuracy: 0.7369 - val_loss: 1.3295
# Epoch 157/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 75ms/step - accuracy: 0.9711 - loss: 0.0864 - val_accuracy: 0.7396 - val_loss: 1.3228
# Epoch 158/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.9683 - loss: 0.0916 - val_accuracy: 0.7356 - val_loss: 1.3639
# Epoch 159/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 75ms/step - accuracy: 0.9692 - loss: 0.0903 - val_accuracy: 0.7360 - val_loss: 1.3631
# Epoch 160/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.9713 - loss: 0.0856 - val_accuracy: 0.7346 - val_loss: 1.3960
# Epoch 161/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 75ms/step - accuracy: 0.9697 - loss: 0.0907 - val_accuracy: 0.7385 - val_loss: 1.4053
# Epoch 162/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.9691 - loss: 0.0888 - val_accuracy: 0.7389 - val_loss: 1.3565
# Epoch 163/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 76ms/step - accuracy: 0.9692 - loss: 0.0914 - val_accuracy: 0.7454 - val_loss: 1.3317
# Epoch 164/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.9707 - loss: 0.0869 - val_accuracy: 0.7384 - val_loss: 1.3890
# Epoch 165/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 76ms/step - accuracy: 0.9721 - loss: 0.0840 - val_accuracy: 0.7333 - val_loss: 1.4025
# Epoch 166/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 75ms/step - accuracy: 0.9711 - loss: 0.0853 - val_accuracy: 0.7412 - val_loss: 1.3686
# Epoch 167/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 77ms/step - accuracy: 0.9709 - loss: 0.0853 - val_accuracy: 0.7394 - val_loss: 1.3619
# Epoch 168/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 75ms/step - accuracy: 0.9654 - loss: 0.0964 - val_accuracy: 0.7399 - val_loss: 1.3787
# Epoch 169/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 77ms/step - accuracy: 0.9741 - loss: 0.0789 - val_accuracy: 0.7346 - val_loss: 1.3878
# Epoch 170/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 76ms/step - accuracy: 0.9711 - loss: 0.0842 - val_accuracy: 0.7375 - val_loss: 1.4217
# Epoch 171/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 76ms/step - accuracy: 0.9711 - loss: 0.0841 - val_accuracy: 0.7295 - val_loss: 1.4582
# Epoch 172/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 76ms/step - accuracy: 0.9691 - loss: 0.0870 - val_accuracy: 0.7362 - val_loss: 1.4078
# Epoch 173/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 76ms/step - accuracy: 0.9717 - loss: 0.0825 - val_accuracy: 0.7390 - val_loss: 1.3805
# Epoch 174/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 75ms/step - accuracy: 0.9710 - loss: 0.0854 - val_accuracy: 0.7371 - val_loss: 1.4153
# Epoch 175/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 76ms/step - accuracy: 0.9759 - loss: 0.0761 - val_accuracy: 0.7316 - val_loss: 1.4471
# Epoch 176/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 75ms/step - accuracy: 0.9706 - loss: 0.0846 - val_accuracy: 0.7378 - val_loss: 1.3846
# Epoch 177/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 76ms/step - accuracy: 0.9720 - loss: 0.0806 - val_accuracy: 0.7385 - val_loss: 1.4458
# Epoch 178/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 75ms/step - accuracy: 0.9711 - loss: 0.0823 - val_accuracy: 0.7334 - val_loss: 1.4065
# Epoch 179/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 77ms/step - accuracy: 0.9726 - loss: 0.0814 - val_accuracy: 0.7389 - val_loss: 1.3859
# Epoch 180/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 75ms/step - accuracy: 0.9724 - loss: 0.0794 - val_accuracy: 0.7374 - val_loss: 1.3896
# Epoch 181/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 77ms/step - accuracy: 0.9720 - loss: 0.0824 - val_accuracy: 0.7364 - val_loss: 1.4191
# Epoch 182/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 76ms/step - accuracy: 0.9706 - loss: 0.0858 - val_accuracy: 0.7329 - val_loss: 1.4410
# Epoch 183/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9749 - loss: 0.0780 - val_accuracy: 0.7364 - val_loss: 1.4641
# Epoch 184/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 76ms/step - accuracy: 0.9733 - loss: 0.0806 - val_accuracy: 0.7345 - val_loss: 1.4555
# Epoch 185/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 77ms/step - accuracy: 0.9758 - loss: 0.0731 - val_accuracy: 0.7395 - val_loss: 1.4342
# Epoch 186/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 76ms/step - accuracy: 0.9735 - loss: 0.0795 - val_accuracy: 0.7407 - val_loss: 1.4273
# Epoch 187/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9738 - loss: 0.0774 - val_accuracy: 0.7390 - val_loss: 1.4318
# Epoch 188/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 77ms/step - accuracy: 0.9721 - loss: 0.0808 - val_accuracy: 0.7324 - val_loss: 1.4670
# Epoch 189/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9762 - loss: 0.0713 - val_accuracy: 0.7407 - val_loss: 1.4461
# Epoch 190/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 76ms/step - accuracy: 0.9750 - loss: 0.0718 - val_accuracy: 0.7234 - val_loss: 1.5816
# Epoch 191/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9761 - loss: 0.0722 - val_accuracy: 0.7410 - val_loss: 1.4688
# Epoch 192/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 77ms/step - accuracy: 0.9734 - loss: 0.0762 - val_accuracy: 0.7390 - val_loss: 1.4299
# Epoch 193/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9774 - loss: 0.0674 - val_accuracy: 0.7386 - val_loss: 1.4934
# Epoch 194/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 77ms/step - accuracy: 0.9756 - loss: 0.0721 - val_accuracy: 0.7382 - val_loss: 1.4776
# Epoch 195/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9738 - loss: 0.0731 - val_accuracy: 0.7375 - val_loss: 1.4733
# Epoch 196/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 77ms/step - accuracy: 0.9709 - loss: 0.0833 - val_accuracy: 0.7380 - val_loss: 1.4503
# Epoch 197/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9780 - loss: 0.0661 - val_accuracy: 0.7358 - val_loss: 1.4833
# Epoch 198/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 77ms/step - accuracy: 0.9750 - loss: 0.0730 - val_accuracy: 0.7406 - val_loss: 1.4703
# Epoch 199/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9764 - loss: 0.0701 - val_accuracy: 0.7388 - val_loss: 1.4527
# Epoch 200/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 77ms/step - accuracy: 0.9769 - loss: 0.0677 - val_accuracy: 0.7340 - val_loss: 1.5072
# Epoch 201/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 79ms/step - accuracy: 0.9776 - loss: 0.0686 - val_accuracy: 0.7318 - val_loss: 1.5559
# Epoch 202/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9752 - loss: 0.0732 - val_accuracy: 0.7350 - val_loss: 1.4865
# Epoch 203/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 79ms/step - accuracy: 0.9769 - loss: 0.0676 - val_accuracy: 0.7390 - val_loss: 1.4424
# Epoch 204/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9754 - loss: 0.0693 - val_accuracy: 0.7306 - val_loss: 1.5057
# Epoch 205/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 79ms/step - accuracy: 0.9768 - loss: 0.0678 - val_accuracy: 0.7380 - val_loss: 1.4762
# Epoch 206/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9773 - loss: 0.0676 - val_accuracy: 0.7419 - val_loss: 1.4676
# Epoch 207/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 79ms/step - accuracy: 0.9802 - loss: 0.0612 - val_accuracy: 0.7386 - val_loss: 1.5263
# Epoch 208/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9771 - loss: 0.0653 - val_accuracy: 0.7441 - val_loss: 1.4671
# Epoch 209/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 79ms/step - accuracy: 0.9765 - loss: 0.0687 - val_accuracy: 0.7365 - val_loss: 1.5346
# Epoch 210/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9782 - loss: 0.0655 - val_accuracy: 0.7416 - val_loss: 1.5026
# Epoch 211/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 80ms/step - accuracy: 0.9748 - loss: 0.0725 - val_accuracy: 0.7398 - val_loss: 1.4762
# Epoch 212/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 78ms/step - accuracy: 0.9781 - loss: 0.0647 - val_accuracy: 0.7381 - val_loss: 1.5074
# Epoch 213/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 80ms/step - accuracy: 0.9751 - loss: 0.0699 - val_accuracy: 0.7417 - val_loss: 1.4932
# Epoch 214/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 61s 79ms/step - accuracy: 0.9789 - loss: 0.0643 - val_accuracy: 0.7317 - val_loss: 1.5324
# Epoch 215/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 80ms/step - accuracy: 0.9757 - loss: 0.0731 - val_accuracy: 0.7373 - val_loss: 1.5433
# Epoch 216/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 80ms/step - accuracy: 0.9768 - loss: 0.0678 - val_accuracy: 0.7387 - val_loss: 1.5168
# Epoch 217/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 81ms/step - accuracy: 0.9784 - loss: 0.0660 - val_accuracy: 0.7404 - val_loss: 1.5153
# Epoch 218/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 79ms/step - accuracy: 0.9770 - loss: 0.0666 - val_accuracy: 0.7332 - val_loss: 1.5272
# Epoch 219/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 80ms/step - accuracy: 0.9769 - loss: 0.0655 - val_accuracy: 0.7312 - val_loss: 1.5333
# Epoch 220/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 79ms/step - accuracy: 0.9791 - loss: 0.0631 - val_accuracy: 0.7433 - val_loss: 1.5027
# Epoch 221/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 81ms/step - accuracy: 0.9790 - loss: 0.0632 - val_accuracy: 0.7364 - val_loss: 1.5710
# Epoch 222/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 79ms/step - accuracy: 0.9750 - loss: 0.0721 - val_accuracy: 0.7421 - val_loss: 1.5434
# Epoch 223/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 81ms/step - accuracy: 0.9767 - loss: 0.0680 - val_accuracy: 0.7410 - val_loss: 1.5286
# Epoch 224/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 80ms/step - accuracy: 0.9794 - loss: 0.0608 - val_accuracy: 0.7377 - val_loss: 1.5427
# Epoch 225/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 81ms/step - accuracy: 0.9786 - loss: 0.0628 - val_accuracy: 0.7384 - val_loss: 1.5439
# Epoch 226/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 80ms/step - accuracy: 0.9785 - loss: 0.0601 - val_accuracy: 0.7375 - val_loss: 1.5583
# Epoch 227/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.9776 - loss: 0.0653 - val_accuracy: 0.7390 - val_loss: 1.5368
# Epoch 228/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 80ms/step - accuracy: 0.9796 - loss: 0.0605 - val_accuracy: 0.7401 - val_loss: 1.5639
# Epoch 229/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.9791 - loss: 0.0616 - val_accuracy: 0.7384 - val_loss: 1.5476
# Epoch 230/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 81ms/step - accuracy: 0.9798 - loss: 0.0605 - val_accuracy: 0.7399 - val_loss: 1.5433
# Epoch 231/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 82ms/step - accuracy: 0.9758 - loss: 0.0692 - val_accuracy: 0.7418 - val_loss: 1.5394
# Epoch 232/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 80ms/step - accuracy: 0.9806 - loss: 0.0580 - val_accuracy: 0.7321 - val_loss: 1.6073
# Epoch 233/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.9786 - loss: 0.0640 - val_accuracy: 0.7358 - val_loss: 1.5873
# Epoch 234/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 81ms/step - accuracy: 0.9798 - loss: 0.0615 - val_accuracy: 0.7382 - val_loss: 1.5480
# Epoch 235/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.9768 - loss: 0.0668 - val_accuracy: 0.7391 - val_loss: 1.5768
# Epoch 236/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 81ms/step - accuracy: 0.9801 - loss: 0.0578 - val_accuracy: 0.7365 - val_loss: 1.5802
# Epoch 237/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.9813 - loss: 0.0565 - val_accuracy: 0.7377 - val_loss: 1.5612
# Epoch 238/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 81ms/step - accuracy: 0.9794 - loss: 0.0609 - val_accuracy: 0.7379 - val_loss: 1.5919
# Epoch 239/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 82ms/step - accuracy: 0.9765 - loss: 0.0673 - val_accuracy: 0.7351 - val_loss: 1.6188
# Epoch 240/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 81ms/step - accuracy: 0.9777 - loss: 0.0654 - val_accuracy: 0.7352 - val_loss: 1.5743
# Epoch 241/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.9785 - loss: 0.0593 - val_accuracy: 0.7334 - val_loss: 1.6077
# Epoch 242/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 81ms/step - accuracy: 0.9792 - loss: 0.0602 - val_accuracy: 0.7389 - val_loss: 1.5735
# Epoch 243/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.9779 - loss: 0.0631 - val_accuracy: 0.7410 - val_loss: 1.5764
# Epoch 244/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 81ms/step - accuracy: 0.9819 - loss: 0.0548 - val_accuracy: 0.7359 - val_loss: 1.6009
# Epoch 245/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.9830 - loss: 0.0539 - val_accuracy: 0.7375 - val_loss: 1.5914
# Epoch 246/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.9796 - loss: 0.0602 - val_accuracy: 0.7367 - val_loss: 1.6190
# Epoch 247/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.9802 - loss: 0.0574 - val_accuracy: 0.7366 - val_loss: 1.5721
# Epoch 248/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.9806 - loss: 0.0573 - val_accuracy: 0.7391 - val_loss: 1.6010
# Epoch 249/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 84ms/step - accuracy: 0.9811 - loss: 0.0565 - val_accuracy: 0.7426 - val_loss: 1.5770
# Epoch 250/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.9805 - loss: 0.0571 - val_accuracy: 0.7335 - val_loss: 1.6363
# Epoch 251/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 84ms/step - accuracy: 0.9811 - loss: 0.0582 - val_accuracy: 0.7354 - val_loss: 1.6042
# Epoch 252/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.9819 - loss: 0.0539 - val_accuracy: 0.7365 - val_loss: 1.6425
# Epoch 253/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 84ms/step - accuracy: 0.9786 - loss: 0.0599 - val_accuracy: 0.7350 - val_loss: 1.6023
# Epoch 254/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.9791 - loss: 0.0596 - val_accuracy: 0.7434 - val_loss: 1.5886
# Epoch 255/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 84ms/step - accuracy: 0.9821 - loss: 0.0548 - val_accuracy: 0.7337 - val_loss: 1.6546
# Epoch 256/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.9823 - loss: 0.0522 - val_accuracy: 0.7360 - val_loss: 1.6603
# Epoch 257/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 84ms/step - accuracy: 0.9802 - loss: 0.0568 - val_accuracy: 0.7355 - val_loss: 1.6400
# Epoch 258/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.9806 - loss: 0.0583 - val_accuracy: 0.7333 - val_loss: 1.6089
# Epoch 259/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 85ms/step - accuracy: 0.9828 - loss: 0.0519 - val_accuracy: 0.7313 - val_loss: 1.6592
# Epoch 260/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 83ms/step - accuracy: 0.9823 - loss: 0.0512 - val_accuracy: 0.7392 - val_loss: 1.6373
# Epoch 261/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 85ms/step - accuracy: 0.9823 - loss: 0.0503 - val_accuracy: 0.7351 - val_loss: 1.6351
# Epoch 262/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 84ms/step - accuracy: 0.9803 - loss: 0.0577 - val_accuracy: 0.7336 - val_loss: 1.6704
# Epoch 263/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 85ms/step - accuracy: 0.9803 - loss: 0.0579 - val_accuracy: 0.7354 - val_loss: 1.6411
# Epoch 264/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 84ms/step - accuracy: 0.9796 - loss: 0.0594 - val_accuracy: 0.7298 - val_loss: 1.6840
# Epoch 265/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 85ms/step - accuracy: 0.9825 - loss: 0.0522 - val_accuracy: 0.7352 - val_loss: 1.6643
# Epoch 266/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 84ms/step - accuracy: 0.9802 - loss: 0.0565 - val_accuracy: 0.7273 - val_loss: 1.7289
# Epoch 267/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 85ms/step - accuracy: 0.9823 - loss: 0.0518 - val_accuracy: 0.7328 - val_loss: 1.6512
# Epoch 268/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 84ms/step - accuracy: 0.9840 - loss: 0.0497 - val_accuracy: 0.7328 - val_loss: 1.6596
# Epoch 269/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 86ms/step - accuracy: 0.9824 - loss: 0.0520 - val_accuracy: 0.7364 - val_loss: 1.6662
# Epoch 270/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 85ms/step - accuracy: 0.9814 - loss: 0.0525 - val_accuracy: 0.7365 - val_loss: 1.6638
# Epoch 271/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.9800 - loss: 0.0560 - val_accuracy: 0.7364 - val_loss: 1.6651
# Epoch 272/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 85ms/step - accuracy: 0.9819 - loss: 0.0519 - val_accuracy: 0.7391 - val_loss: 1.6768
# Epoch 273/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.9823 - loss: 0.0542 - val_accuracy: 0.7382 - val_loss: 1.6635
# Epoch 274/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 85ms/step - accuracy: 0.9830 - loss: 0.0507 - val_accuracy: 0.7315 - val_loss: 1.6728
# Epoch 275/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 86ms/step - accuracy: 0.9847 - loss: 0.0477 - val_accuracy: 0.7349 - val_loss: 1.7023
# Epoch 276/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 90ms/step - accuracy: 0.9847 - loss: 0.0471 - val_accuracy: 0.7371 - val_loss: 1.6642
# Epoch 277/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 89ms/step - accuracy: 0.9817 - loss: 0.0544 - val_accuracy: 0.7385 - val_loss: 1.6963
# Epoch 278/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 85ms/step - accuracy: 0.9829 - loss: 0.0482 - val_accuracy: 0.7360 - val_loss: 1.7036
# Epoch 279/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.9821 - loss: 0.0536 - val_accuracy: 0.7285 - val_loss: 1.7244
# Epoch 280/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 86ms/step - accuracy: 0.9830 - loss: 0.0527 - val_accuracy: 0.7309 - val_loss: 1.7256
# Epoch 281/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.9812 - loss: 0.0550 - val_accuracy: 0.7316 - val_loss: 1.7097
# Epoch 282/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.9827 - loss: 0.0508 - val_accuracy: 0.7422 - val_loss: 1.6597
# Epoch 283/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.9837 - loss: 0.0472 - val_accuracy: 0.7392 - val_loss: 1.6774
# Epoch 284/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.9825 - loss: 0.0515 - val_accuracy: 0.7400 - val_loss: 1.6774
# Epoch 285/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.9816 - loss: 0.0534 - val_accuracy: 0.7348 - val_loss: 1.6763
# Epoch 286/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.9853 - loss: 0.0451 - val_accuracy: 0.7325 - val_loss: 1.7139
# Epoch 287/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.9814 - loss: 0.0528 - val_accuracy: 0.7347 - val_loss: 1.6737
# Epoch 288/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 86ms/step - accuracy: 0.9840 - loss: 0.0487 - val_accuracy: 0.7401 - val_loss: 1.7046
# Epoch 289/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.9815 - loss: 0.0533 - val_accuracy: 0.7247 - val_loss: 1.7806
# Epoch 290/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.9837 - loss: 0.0473 - val_accuracy: 0.7366 - val_loss: 1.7200
# Epoch 291/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.9819 - loss: 0.0527 - val_accuracy: 0.7354 - val_loss: 1.6920
# Epoch 292/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 86ms/step - accuracy: 0.9840 - loss: 0.0468 - val_accuracy: 0.7353 - val_loss: 1.7515
# Epoch 293/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.9850 - loss: 0.0463 - val_accuracy: 0.7356 - val_loss: 1.7111
# Epoch 294/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.9846 - loss: 0.0458 - val_accuracy: 0.7360 - val_loss: 1.6899
# Epoch 295/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.9845 - loss: 0.0476 - val_accuracy: 0.7324 - val_loss: 1.7396
# Epoch 296/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.9812 - loss: 0.0555 - val_accuracy: 0.7378 - val_loss: 1.6988
# Epoch 297/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.9836 - loss: 0.0481 - val_accuracy: 0.7328 - val_loss: 1.7273
# Epoch 298/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.9840 - loss: 0.0464 - val_accuracy: 0.7333 - val_loss: 1.7071
# Epoch 299/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 89ms/step - accuracy: 0.9830 - loss: 0.0508 - val_accuracy: 0.7382 - val_loss: 1.6736
# Epoch 300/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.9808 - loss: 0.0530 - val_accuracy: 0.7328 - val_loss: 1.7237
# Epoch 301/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 89ms/step - accuracy: 0.9838 - loss: 0.0459 - val_accuracy: 0.7317 - val_loss: 1.7715
# Epoch 302/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.9831 - loss: 0.0489 - val_accuracy: 0.7353 - val_loss: 1.7139
# Epoch 303/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 89ms/step - accuracy: 0.9823 - loss: 0.0514 - val_accuracy: 0.7309 - val_loss: 1.7432
# Epoch 304/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.9864 - loss: 0.0419 - val_accuracy: 0.7346 - val_loss: 1.7321
# Epoch 305/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 89ms/step - accuracy: 0.9826 - loss: 0.0489 - val_accuracy: 0.7315 - val_loss: 1.7724
# Epoch 306/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.9832 - loss: 0.0506 - val_accuracy: 0.7380 - val_loss: 1.7438
# Epoch 307/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 89ms/step - accuracy: 0.9839 - loss: 0.0478 - val_accuracy: 0.7319 - val_loss: 1.7300
# Epoch 308/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.9830 - loss: 0.0510 - val_accuracy: 0.7370 - val_loss: 1.7240
# Epoch 309/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 90ms/step - accuracy: 0.9839 - loss: 0.0467 - val_accuracy: 0.7288 - val_loss: 1.7803
# Epoch 310/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 89ms/step - accuracy: 0.9867 - loss: 0.0409 - val_accuracy: 0.7401 - val_loss: 1.7270
# Epoch 311/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 90ms/step - accuracy: 0.9827 - loss: 0.0501 - val_accuracy: 0.7365 - val_loss: 1.7391
# Epoch 312/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 89ms/step - accuracy: 0.9853 - loss: 0.0440 - val_accuracy: 0.7353 - val_loss: 1.7384
# Epoch 313/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.9855 - loss: 0.0429 - val_accuracy: 0.7339 - val_loss: 1.7730
# Epoch 314/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 90ms/step - accuracy: 0.9846 - loss: 0.0472 - val_accuracy: 0.7322 - val_loss: 1.7631
# Epoch 315/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 92ms/step - accuracy: 0.9815 - loss: 0.0538 - val_accuracy: 0.7339 - val_loss: 1.7745
# Epoch 316/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.9854 - loss: 0.0444 - val_accuracy: 0.7302 - val_loss: 1.7729
# Epoch 317/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 93ms/step - accuracy: 0.9827 - loss: 0.0481 - val_accuracy: 0.7297 - val_loss: 1.8074
# Epoch 318/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.9844 - loss: 0.0465 - val_accuracy: 0.7335 - val_loss: 1.7804
# Epoch 319/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 92ms/step - accuracy: 0.9866 - loss: 0.0424 - val_accuracy: 0.7377 - val_loss: 1.7342
# Epoch 320/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 92ms/step - accuracy: 0.9854 - loss: 0.0444 - val_accuracy: 0.7382 - val_loss: 1.7426
# Epoch 321/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 74s 94ms/step - accuracy: 0.9843 - loss: 0.0458 - val_accuracy: 0.7346 - val_loss: 1.7865
# Epoch 322/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 92ms/step - accuracy: 0.9851 - loss: 0.0465 - val_accuracy: 0.7292 - val_loss: 1.7913
# Epoch 323/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 74s 94ms/step - accuracy: 0.9847 - loss: 0.0457 - val_accuracy: 0.7311 - val_loss: 1.7796
# Epoch 324/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 93ms/step - accuracy: 0.9849 - loss: 0.0449 - val_accuracy: 0.7343 - val_loss: 1.7960
# Epoch 325/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 94ms/step - accuracy: 0.9841 - loss: 0.0454 - val_accuracy: 0.7290 - val_loss: 1.7413
# Epoch 326/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 92ms/step - accuracy: 0.9825 - loss: 0.0506 - val_accuracy: 0.7309 - val_loss: 1.7710
# Epoch 327/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 93ms/step - accuracy: 0.9864 - loss: 0.0407 - val_accuracy: 0.7349 - val_loss: 1.8008
# Epoch 328/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 92ms/step - accuracy: 0.9832 - loss: 0.0482 - val_accuracy: 0.7349 - val_loss: 1.7836
# Epoch 329/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 94ms/step - accuracy: 0.9854 - loss: 0.0447 - val_accuracy: 0.7329 - val_loss: 1.7543
# Epoch 330/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 93ms/step - accuracy: 0.9828 - loss: 0.0503 - val_accuracy: 0.7331 - val_loss: 1.7779
# Epoch 331/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 94ms/step - accuracy: 0.9851 - loss: 0.0432 - val_accuracy: 0.7365 - val_loss: 1.7624
# Epoch 332/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 93ms/step - accuracy: 0.9846 - loss: 0.0453 - val_accuracy: 0.7358 - val_loss: 1.7540
# Epoch 333/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 74s 95ms/step - accuracy: 0.9859 - loss: 0.0412 - val_accuracy: 0.7346 - val_loss: 1.7908
# Epoch 334/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 93ms/step - accuracy: 0.9834 - loss: 0.0492 - val_accuracy: 0.7341 - val_loss: 1.8058
# Epoch 335/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 74s 95ms/step - accuracy: 0.9852 - loss: 0.0447 - val_accuracy: 0.7319 - val_loss: 1.8115
# Epoch 336/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 94ms/step - accuracy: 0.9874 - loss: 0.0382 - val_accuracy: 0.7352 - val_loss: 1.7964
# Epoch 337/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 95ms/step - accuracy: 0.9860 - loss: 0.0439 - val_accuracy: 0.7335 - val_loss: 1.7899
# Epoch 338/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 93ms/step - accuracy: 0.9866 - loss: 0.0403 - val_accuracy: 0.7342 - val_loss: 1.8280
# Epoch 339/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 74s 95ms/step - accuracy: 0.9845 - loss: 0.0453 - val_accuracy: 0.7353 - val_loss: 1.8050
# Epoch 340/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 94ms/step - accuracy: 0.9851 - loss: 0.0423 - val_accuracy: 0.7346 - val_loss: 1.8263
# Epoch 341/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 74s 95ms/step - accuracy: 0.9866 - loss: 0.0410 - val_accuracy: 0.7394 - val_loss: 1.7654
# Epoch 342/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 94ms/step - accuracy: 0.9854 - loss: 0.0425 - val_accuracy: 0.7327 - val_loss: 1.8156
# Epoch 343/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 95ms/step - accuracy: 0.9845 - loss: 0.0440 - val_accuracy: 0.7346 - val_loss: 1.7966
# Epoch 344/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 74s 94ms/step - accuracy: 0.9854 - loss: 0.0432 - val_accuracy: 0.7325 - val_loss: 1.8257
# Epoch 345/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 96ms/step - accuracy: 0.9855 - loss: 0.0435 - val_accuracy: 0.7277 - val_loss: 1.8607
# Epoch 346/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 74s 95ms/step - accuracy: 0.9863 - loss: 0.0398 - val_accuracy: 0.7316 - val_loss: 1.8129
# Epoch 347/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 96ms/step - accuracy: 0.9812 - loss: 0.0535 - val_accuracy: 0.7363 - val_loss: 1.7919
# Epoch 348/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 95ms/step - accuracy: 0.9863 - loss: 0.0405 - val_accuracy: 0.7364 - val_loss: 1.7927
# Epoch 349/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 97ms/step - accuracy: 0.9868 - loss: 0.0390 - val_accuracy: 0.7368 - val_loss: 1.8001
# Epoch 350/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 95ms/step - accuracy: 0.9854 - loss: 0.0435 - val_accuracy: 0.7397 - val_loss: 1.8082
# Epoch 351/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 97ms/step - accuracy: 0.9864 - loss: 0.0401 - val_accuracy: 0.7377 - val_loss: 1.8129
# Epoch 352/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 95ms/step - accuracy: 0.9861 - loss: 0.0412 - val_accuracy: 0.7355 - val_loss: 1.8002
# Epoch 353/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 97ms/step - accuracy: 0.9853 - loss: 0.0431 - val_accuracy: 0.7352 - val_loss: 1.8239
# Epoch 354/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 96ms/step - accuracy: 0.9852 - loss: 0.0465 - val_accuracy: 0.7363 - val_loss: 1.8109
# Epoch 355/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 97ms/step - accuracy: 0.9877 - loss: 0.0358 - val_accuracy: 0.7380 - val_loss: 1.8785
# Epoch 356/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 96ms/step - accuracy: 0.9859 - loss: 0.0401 - val_accuracy: 0.7374 - val_loss: 1.8440
# Epoch 357/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 98ms/step - accuracy: 0.9843 - loss: 0.0445 - val_accuracy: 0.7292 - val_loss: 1.9124
# Epoch 358/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 96ms/step - accuracy: 0.9869 - loss: 0.0397 - val_accuracy: 0.7343 - val_loss: 1.8207
# Epoch 359/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 98ms/step - accuracy: 0.9857 - loss: 0.0418 - val_accuracy: 0.7342 - val_loss: 1.8373
# Epoch 360/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 97ms/step - accuracy: 0.9856 - loss: 0.0413 - val_accuracy: 0.7402 - val_loss: 1.8129
# Epoch 361/501
# ...
#  0.74650002 0.75260001 0.75690001 0.7561     0.75349998 0.7493
#  0.75300002 0.75660002 0.75419998 0.75419998 0.74910003 0.74699998
#  0.7543     0.75590003 0.75410002 0.75040001 0.7543     0.7403
#  0.74370003 0.74529999 0.75919998 0.75950003 0.75389999 0.75639999
#  0.7489     0.75300002 0.74559999 0.75510001 0.7572     0.74169999
#  0.75639999 0.74800003 0.76109999 0.75199997 0.7561     0.74669999
#  0.7543     0.7561     0.75470001 0.75010002 0.74980003 0.75230002
#  0.75340003 0.74989998 0.75590003 0.75160003 0.75550002 0.75440001
#  0.75910002 0.75279999 0.75029999 0.74900001 0.75190002 0.75580001
#  0.75089997 0.75099999 0.75349998 0.7511     0.74720001 0.74919999
#  0.75440001 0.7543     0.74580002 0.7493     0.75419998 0.75220001
#  0.75620002 0.7432     0.75190002 0.74830002 0.75040001 0.75569999
#  0.75190002 0.74860001 0.75749999 0.74470001 0.74949998 0.75330001
#  0.74690002 0.7529     0.7572     0.75590003 0.75340003 0.74769998
#  0.75019997 0.75029999 0.759      0.75139999 0.7536     0.76010001
#  0.76120001 0.75950003 0.75050002 0.75650001 0.75440001 0.74440002
#  0.75340003 0.74620003 0.7529     0.75550002 0.74900001 0.75449997
#  0.75400001 0.75269997 0.74900001 0.75279999 0.75880003 0.75760001
#  0.75089997 0.7489     0.75449997 0.75330001 0.7529     0.74680001
#  0.74830002 0.74739999 0.75370002 0.75220001 0.7518     0.75309998
#  0.75340003 0.75089997 0.7475     0.75440001 0.75400001 0.74250001
#  0.7586     0.75269997 0.74949998 0.75999999 0.74659997 0.74910003
#  0.75620002 0.7446     0.7525    ]
#   val_loss: [1.49116886 1.3113116  1.03111911 0.94200897 0.9861508  1.01024497
#  0.91641718 0.93221182 0.89768362 0.95135647 0.94608504 1.02657056
#  0.8099789  0.95638698 0.79219955 0.82504445 0.78717309 0.86801946
#  0.94937015 0.78190911 0.75090903 0.81210923 0.83012766 0.88974875
#  0.83268547 0.88520467 0.77356738 0.85941738 0.84000009 0.81421936
#  0.84931064 0.92230976 0.88615996 0.8093968  0.87056768 0.83359784
#  0.89881867 0.8668496  0.88567901 0.83269304 0.93741882 0.93042976
#  0.90979999 0.90839666 0.85977668 0.85137278 0.84874982 0.85999632
#  0.88687366 1.06267381 0.92449856 0.87937677 0.88046414 0.83474123
#  0.81947333 0.89135683 0.88943976 0.91717869 0.88892031 0.89772266
#  0.88585764 0.94435751 0.90790761 0.87800282 0.86811942 0.87259394
#  0.92169619 0.9488166  0.95361876 0.99718493 1.03440487 0.919976
#  0.99757522 0.91381121 0.90431738 1.00494754 0.9536953  0.97194016
#  0.93362528 0.94766212 0.97524649 1.08643651 0.96613652 1.04744136
#  0.97624338 0.95519626 0.97894979 1.1737057  1.06225896 0.98507136
#  1.06943035 1.01798451 1.02649808 1.04836929 0.95561355 1.0208714
#  1.01809907 1.06508648 1.00743663 1.02264738 0.99988621 1.01325774
#  1.01495707 0.99601543 1.0234493  1.04040396 1.06773031 1.04444957
#  1.0617398  1.05094802 1.01622617 1.11418045 1.12437177 1.0999012
#  1.0178386  1.07642734 1.0463444  1.05162859 1.0803932  1.02844858
#  1.06065893 1.0486995  1.10340154 1.08150911 1.10882568 1.05739164
#  1.16036022 1.08507681 1.12407982 1.23793674 1.10505331 1.08302665
#  1.10465729 1.15591073 1.0958221  1.08713615 1.10411143 1.1268003
#  1.07690287 1.14335966 1.17557323 1.12870157 1.15144336 1.12444377
#  1.16566741 1.16396141 1.13718748 1.1263417  1.17357397 1.15293753
#  1.18423462 1.12564826 1.18835187 1.09525657 1.11856508 1.12676001
#  1.16928422 1.2201649  1.20947444 1.18899477 1.23464167 1.23786271
#  1.23092735 1.12935996 1.20020998 1.16855884 1.23280454 1.11687469
#  1.17075586 1.17417502 1.25787258 1.21426988 1.17945528 1.32402885
#  1.19690454 1.19585609 1.23014164 1.28747487 1.23247552 1.24206555
#  1.2229315  1.28304458 1.19834483 1.34587872 1.22946143 1.16285872
#  1.21202302 1.22704291 1.24120474 1.22306204 1.31038785 1.21738911
#  1.32876289 1.23641956 1.23822987 1.25245976 1.25139391 1.26141644
#  1.26031554 1.26894701 1.2220273  1.24899197 1.26351905 1.20243979
#  1.24568796 1.27759349 1.23982668 1.27611196 1.27676523 1.27670896
#  1.23446476 1.23196793 1.33765531 1.26880658 1.3031131  1.28515458
#  1.31399083 1.3828007  1.2969768  1.25424707 1.35155785 1.24804759
#  1.32782018 1.29973423 1.27471304 1.32410181 1.2527051  1.28111517
#  1.27428889 1.27943385 1.33827317 1.37725818 1.28027797 1.29524076
#  1.34990811 1.32808661 1.39717495 1.38834465 1.37043762 1.2765193
#  1.27929986 1.29974985 1.39189696 1.34161854 1.34025288 1.29758608
#  1.29172969 1.32854962 1.40973794 1.34211838 1.40786409 1.29557168
#  1.38296402 1.30018139 1.32804084 1.47629023 1.3880645  1.34594023
#  1.35416174 1.36045647 1.3322202  1.39200425 1.34860909 1.32919085
#  1.34262943 1.3550483  1.32801414 1.3887502  1.43448162 1.40415597
#  1.34854889 1.38728189 1.35145879 1.38259137 1.36647832 1.40199161
#  1.51231515 1.34783959 1.37793434 1.42699039 1.44270551 1.44628656
#  1.39676642 1.37430143 1.3501122  1.47043312 1.38757455 1.40812027
#  1.42340028 1.43321824 1.51283336 1.36333358 1.38661957 1.37069142
#  1.38478518 1.38321292 1.44603539 1.46574092 1.41067886 1.40080214
#  1.4432801  1.41705859 1.40814614 1.43977427 1.47129714 1.57545328
#  1.40177643 1.47790873 1.40725815 1.47697091 1.46300042 1.46243036
#  1.44779754 1.49963987 1.44572031 1.44715083 1.46747553 1.46402752
#  1.41176915 1.48391902 1.4332602  1.40039635 1.38886762 1.433653
#  1.4154613  1.53566217 1.44044828 1.42491281 1.48565805 1.44321096
#  1.42193866 1.44155502 1.51234233 1.51205719 1.43117857 1.4932071
#  1.4072479  1.4511162  1.51107728 1.41804874 1.39184439 1.40681529
#  1.42915308 1.52636635 1.44647467 1.56994629 1.47684872 1.50095403
#  1.49502528 1.43920279 1.44672811 1.48711872 1.45269001 1.46374047
#  1.54874146 1.53525591 1.4959228  1.54001355 1.4719739  1.48639953
#  1.44578254 1.5323602  1.49602592 1.50858748 1.45282221 1.46723866
#  1.58146656 1.52249396 1.46073794 1.48436785 1.53231239 1.55189085
#  1.50422323 1.49101412 1.51514196 1.48870862 1.52034843 1.58395565
#  1.5319649  1.47379422 1.47489202 1.54520416 1.49759293 1.55135965
#  1.58159971 1.55192733 1.48246944 1.47196925 1.47017634 1.49333417
#  1.52245927 1.51425755 1.54991591 1.49535537 1.4644022  1.54866779
#  1.51752877 1.56447566 1.45218766 1.53434527 1.51559949 1.58182752
#  1.51380122 1.49894333 1.55938947 1.55131483 1.57350278 1.50135171
#  1.54681993 1.56208408 1.52109897 1.53662968 1.50629663 1.55313396
#  1.49807477 1.52995563 1.56258476 1.58476484 1.53226161 1.50390959
#  1.57368314 1.58255374 1.56530893 1.55386531 1.60039818 1.58053601
#  1.50821054 1.55884302 1.57137561 1.54957211 1.56250739 1.54043674
#  1.55217957 1.62045193 1.56748903 1.63450623 1.54359007 1.55921006
#  1.56016922 1.52927661 1.56922078 1.64447534 1.5702889  1.56771624
#  1.637923   1.58066261 1.57145154 1.54499578 1.55511904 1.62839389
#  1.57868648 1.59094942 1.54874361 1.60387397 1.54534125 1.54123759
#  1.54781818 1.53625226 1.5821116  1.54667342 1.56447279 1.68042564
#  1.57889426 1.62698102 1.59040558 1.595456   1.58341622 1.56170201
#  1.58123076 1.55533755 1.60019028 1.56511033 1.56292796 1.56695473
#  1.62819028 1.62810683 1.59719849 1.57478738 1.57160914 1.66529393
#  1.57953    1.62729323 1.56781971 1.60358071 1.6302228  1.65982246
#  1.61213338 1.62532997 1.61419022 1.59960294 1.56428218 1.68129683
#  1.5890969  1.58780968 1.637761   1.59461987 1.66161931 1.67520154
#  1.60732079 1.66059554 1.66748285]
# Running: Activation=Swish at 2025-07-21 01:13:41
# Epoch 1/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 142s 176ms/step - accuracy: 0.4339 - loss: 1.5611 - val_accuracy: 0.5412 - val_loss: 1.3163
# Epoch 2/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 137s 175ms/step - accuracy: 0.6204 - loss: 1.0681 - val_accuracy: 0.6169 - val_loss: 1.0705
# Epoch 3/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 137s 175ms/step - accuracy: 0.6715 - loss: 0.9296 - val_accuracy: 0.5996 - val_loss: 1.1550
# Epoch 4/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 136s 174ms/step - accuracy: 0.7085 - loss: 0.8231 - val_accuracy: 0.6443 - val_loss: 1.0241
# Epoch 5/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 136s 174ms/step - accuracy: 0.7293 - loss: 0.7621 - val_accuracy: 0.6810 - val_loss: 0.9090
# Epoch 6/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 136s 173ms/step - accuracy: 0.7515 - loss: 0.7066 - val_accuracy: 0.6828 - val_loss: 0.9339
# Epoch 7/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 136s 174ms/step - accuracy: 0.7674 - loss: 0.6653 - val_accuracy: 0.6960 - val_loss: 0.9276
# Epoch 8/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 136s 174ms/step - accuracy: 0.7799 - loss: 0.6288 - val_accuracy: 0.7223 - val_loss: 0.8036
# Epoch 9/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 135s 173ms/step - accuracy: 0.7869 - loss: 0.6082 - val_accuracy: 0.7291 - val_loss: 0.7983
# Epoch 10/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 136s 174ms/step - accuracy: 0.8029 - loss: 0.5676 - val_accuracy: 0.7266 - val_loss: 0.8177
# Epoch 11/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 136s 174ms/step - accuracy: 0.8060 - loss: 0.5546 - val_accuracy: 0.7376 - val_loss: 0.7678
# Epoch 12/501
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 136s 175ms/step - accuracy: 0.8139 - loss: 0.5310 - val_accuracy: 0.7084 - val_loss: 0.8546
# Epoch 13/501
# 160/782 ━━━━━━━━━━━━━━━━━━━━ 1:47 172ms/step - accuracy: 0.8219 - loss: 0.4965
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 150
#     145 model = build_model(act_fn)
#     146 model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
#     147                     loss='sparse_categorical_crossentropy',
#     148                     metrics=['accuracy'])
# --> 150 history = model.fit(x_train, y_train, epochs=epochs, validation_data=(x_test, y_test), batch_size=batch_size)
#     152 print(f"Running: Activation={act_name} at {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
#     153 results[act_name] = {key: np.array(val) for key, val in history.history.items()}
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:377, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     375 for step, iterator in epoch_iterator:
#     376     callbacks.on_train_batch_begin(step)
# --> 377     logs = self.train_function(iterator)
#     378     callbacks.on_train_batch_end(step, logs)
#     379     if self.stop_training:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:220, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     216 def function(iterator):
#     217     if isinstance(
#     218         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     219     ):
# --> 220         opt_outputs = multi_step_on_iterator(iterator)
#     221         if not opt_outputs.has_value():
#     222             raise StopIteration
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
